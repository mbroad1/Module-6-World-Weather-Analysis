# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 741

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Basic URL for OpenWeatherMap
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce205ca9f8b1b0bb8fe9f2a924edeb40

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Current Description": city_weather_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | rio gallegos
# Processing Record 2 of Set 1 | rikitea
# Processing Record 3 of Set 1 | suntar
# Processing Record 4 of Set 1 | bethel
# Processing Record 5 of Set 1 | ancud
# Processing Record 6 of Set 1 | samarai
# Processing Record 7 of Set 1 | darlowo
# Processing Record 8 of Set 1 | kazalinsk
# City not found. Skipping...
# Processing Record 9 of Set 1 | upernavik
# Processing Record 10 of Set 1 | soubre
# Processing Record 11 of Set 1 | nishihara
# Processing Record 12 of Set 1 | buenos aires
# Processing Record 13 of Set 1 | mataura
# Processing Record 14 of Set 1 | saskylakh
# Processing Record 15 of Set 1 | punta arenas
# Processing Record 16 of Set 1 | yellowknife
# Processing Record 17 of Set 1 | banepa
# Processing Record 18 of Set 1 | golitsyno
# Processing Record 19 of Set 1 | touros
# Processing Record 20 of Set 1 | ushuaia
# Processing Record 21 of Set 1 | kapaa
# Processing Record 22 of Set 1 | saint-philippe
# Processing Record 23 of Set 1 | victoria
# Processing Record 24 of Set 1 | ayapel
# Processing Record 25 of Set 1 | fort nelson
# Processing Record 26 of Set 1 | hermanus
# Processing Record 27 of Set 1 | linjiang
# Processing Record 28 of Set 1 | mangrol
# Processing Record 29 of Set 1 | salalah
# Processing Record 30 of Set 1 | cabra
# Processing Record 31 of Set 1 | castro
# Processing Record 32 of Set 1 | bengkulu
# Processing Record 33 of Set 1 | grand gaube
# Processing Record 34 of Set 1 | seoul
# Processing Record 35 of Set 1 | najran
# Processing Record 36 of Set 1 | butaritari
# Processing Record 37 of Set 1 | pilar
# Processing Record 38 of Set 1 | balkanabat
# Processing Record 39 of Set 1 | torbay
# Processing Record 40 of Set 1 | busselton
# Processing Record 41 of Set 1 | new norfolk
# Processing Record 42 of Set 1 | xichang
# Processing Record 43 of Set 1 | ouadda
# Processing Record 44 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 45 of Set 1 | tuktoyaktuk
# Processing Record 46 of Set 1 | kamaishi
# Processing Record 47 of Set 1 | viedma
# Processing Record 48 of Set 1 | san policarpo
# Processing Record 49 of Set 1 | vaini
# Processing Record 50 of Set 1 | georgetown
# Processing Record 1 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 2 of Set 2 | arman
# Processing Record 3 of Set 2 | springfield
# Processing Record 4 of Set 2 | bokspits
# City not found. Skipping...
# Processing Record 5 of Set 2 | halalo
# City not found. Skipping...
# Processing Record 6 of Set 2 | ambilobe
# Processing Record 7 of Set 2 | waingapu
# Processing Record 8 of Set 2 | mora
# Processing Record 9 of Set 2 | jamestown
# Processing Record 10 of Set 2 | port lincoln
# Processing Record 11 of Set 2 | norman wells
# Processing Record 12 of Set 2 | ribeira grande
# Processing Record 13 of Set 2 | isangel
# Processing Record 14 of Set 2 | ahipara
# Processing Record 15 of Set 2 | carnarvon
# Processing Record 16 of Set 2 | witrivier
# City not found. Skipping...
# Processing Record 17 of Set 2 | richards bay
# Processing Record 18 of Set 2 | kegayli
# City not found. Skipping...
# Processing Record 19 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 20 of Set 2 | hasaki
# Processing Record 21 of Set 2 | louis trichardt
# Processing Record 22 of Set 2 | constitucion
# Processing Record 23 of Set 2 | planaltina
# Processing Record 24 of Set 2 | saldanha
# Processing Record 25 of Set 2 | atuona
# Processing Record 26 of Set 2 | hervey bay
# Processing Record 27 of Set 2 | lata
# Processing Record 28 of Set 2 | codrington
# Processing Record 29 of Set 2 | san rafael
# Processing Record 30 of Set 2 | faanui
# Processing Record 31 of Set 2 | agas
# Processing Record 32 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 33 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 34 of Set 2 | kropotkin
# Processing Record 35 of Set 2 | narsaq
# Processing Record 36 of Set 2 | malinyi
# Processing Record 37 of Set 2 | kpalime
# Processing Record 38 of Set 2 | mahebourg
# Processing Record 39 of Set 2 | shumikha
# Processing Record 40 of Set 2 | avarua
# Processing Record 41 of Set 2 | panguna
# Processing Record 42 of Set 2 | thompson
# Processing Record 43 of Set 2 | hithadhoo
# Processing Record 44 of Set 2 | bilgoraj
# Processing Record 45 of Set 2 | esperance
# Processing Record 46 of Set 2 | manitouwadge
# Processing Record 47 of Set 2 | qaanaaq
# Processing Record 48 of Set 2 | east london
# Processing Record 49 of Set 2 | mar del plata
# Processing Record 50 of Set 2 | damara
# Processing Record 1 of Set 3 | manono
# Processing Record 2 of Set 3 | clyde river
# Processing Record 3 of Set 3 | san jose
# Processing Record 4 of Set 3 | phan rang
# City not found. Skipping...
# Processing Record 5 of Set 3 | atar
# Processing Record 6 of Set 3 | tasiilaq
# Processing Record 7 of Set 3 | bluff
# Processing Record 8 of Set 3 | mastic beach
# Processing Record 9 of Set 3 | te anau
# Processing Record 10 of Set 3 | tiksi
# Processing Record 11 of Set 3 | amli
# Processing Record 12 of Set 3 | dikson
# Processing Record 13 of Set 3 | oshakati
# Processing Record 14 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 15 of Set 3 | geraldton
# Processing Record 16 of Set 3 | beringovskiy
# Processing Record 17 of Set 3 | aswan
# Processing Record 18 of Set 3 | pacific grove
# Processing Record 19 of Set 3 | banda aceh
# Processing Record 20 of Set 3 | pisco
# Processing Record 21 of Set 3 | clinton
# Processing Record 22 of Set 3 | rawson
# Processing Record 23 of Set 3 | stykkisholmur
# Processing Record 24 of Set 3 | mehamn
# Processing Record 25 of Set 3 | bajil
# Processing Record 26 of Set 3 | kaitangata
# Processing Record 27 of Set 3 | bredasdorp
# Processing Record 28 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 29 of Set 3 | sola
# Processing Record 30 of Set 3 | caravelas
# Processing Record 31 of Set 3 | beira
# Processing Record 32 of Set 3 | uddevalla
# Processing Record 33 of Set 3 | albany
# Processing Record 34 of Set 3 | nanortalik
# Processing Record 35 of Set 3 | port elizabeth
# Processing Record 36 of Set 3 | hamilton
# Processing Record 37 of Set 3 | vozdvizhenka
# Processing Record 38 of Set 3 | kununurra
# Processing Record 39 of Set 3 | tawkar
# City not found. Skipping...
# Processing Record 40 of Set 3 | yingshang
# City not found. Skipping...
# Processing Record 41 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 42 of Set 3 | lorengau
# Processing Record 43 of Set 3 | kenai
# Processing Record 44 of Set 3 | teul
# City not found. Skipping...
# Processing Record 45 of Set 3 | kloulklubed
# Processing Record 46 of Set 3 | kuche
# City not found. Skipping...
# Processing Record 47 of Set 3 | vila velha
# Processing Record 48 of Set 3 | isla mujeres
# Processing Record 49 of Set 3 | dindori
# Processing Record 50 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 1 of Set 4 | ceres
# Processing Record 2 of Set 4 | leningradskiy
# Processing Record 3 of Set 4 | ozgon
# City not found. Skipping...
# Processing Record 4 of Set 4 | port macquarie
# Processing Record 5 of Set 4 | karaton
# Processing Record 6 of Set 4 | wilmington island
# Processing Record 7 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 8 of Set 4 | palmer
# Processing Record 9 of Set 4 | cockburn town
# Processing Record 10 of Set 4 | abonnema
# Processing Record 11 of Set 4 | hobart
# Processing Record 12 of Set 4 | sao joao da barra
# Processing Record 13 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 14 of Set 4 | ponta do sol
# Processing Record 15 of Set 4 | broome
# Processing Record 16 of Set 4 | tasbuget
# City not found. Skipping...
# Processing Record 17 of Set 4 | grand centre
# City not found. Skipping...
# Processing Record 18 of Set 4 | tuatapere
# Processing Record 19 of Set 4 | waipawa
# Processing Record 20 of Set 4 | naryan-mar
# Processing Record 21 of Set 4 | gat
# Processing Record 22 of Set 4 | hilo
# Processing Record 23 of Set 4 | dongtai
# Processing Record 24 of Set 4 | khor
# Processing Record 25 of Set 4 | marv dasht
# City not found. Skipping...
# Processing Record 26 of Set 4 | nikolskoye
# Processing Record 27 of Set 4 | pingliang
# Processing Record 28 of Set 4 | shelburne
# Processing Record 29 of Set 4 | kawana waters
# City not found. Skipping...
# Processing Record 30 of Set 4 | faya
# Processing Record 31 of Set 4 | sabzevar
# Processing Record 32 of Set 4 | puerto ayora
# Processing Record 33 of Set 4 | byumba
# Processing Record 34 of Set 4 | ulaangom
# Processing Record 35 of Set 4 | kodiak
# Processing Record 36 of Set 4 | khatanga
# Processing Record 37 of Set 4 | yar-sale
# Processing Record 38 of Set 4 | babushkin
# Processing Record 39 of Set 4 | portland
# Processing Record 40 of Set 4 | pangnirtung
# Processing Record 41 of Set 4 | kosh-agach
# Processing Record 42 of Set 4 | leshukonskoye
# Processing Record 43 of Set 4 | lagos
# Processing Record 44 of Set 4 | marion
# Processing Record 45 of Set 4 | chernyshevskiy
# Processing Record 46 of Set 4 | odda
# Processing Record 47 of Set 4 | maningrida
# Processing Record 48 of Set 4 | iqaluit
# Processing Record 49 of Set 4 | bubaque
# Processing Record 50 of Set 4 | moroni
# Processing Record 1 of Set 5 | bagado
# Processing Record 2 of Set 5 | tucuma
# Processing Record 3 of Set 5 | rock springs
# Processing Record 4 of Set 5 | koulikoro
# Processing Record 5 of Set 5 | mercedes
# Processing Record 6 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 7 of Set 5 | cidreira
# Processing Record 8 of Set 5 | coihaique
# Processing Record 9 of Set 5 | alindao
# Processing Record 10 of Set 5 | gamboma
# Processing Record 11 of Set 5 | puerto escondido
# Processing Record 12 of Set 5 | chishtian mandi
# Processing Record 13 of Set 5 | payo
# Processing Record 14 of Set 5 | barrow
# Processing Record 15 of Set 5 | jambi
# Processing Record 16 of Set 5 | cabo san lucas
# Processing Record 17 of Set 5 | asau
# Processing Record 18 of Set 5 | yeppoon
# Processing Record 19 of Set 5 | talnakh
# Processing Record 20 of Set 5 | cape town
# Processing Record 21 of Set 5 | yarmouth
# Processing Record 22 of Set 5 | zhanaozen
# Processing Record 23 of Set 5 | nagua
# Processing Record 24 of Set 5 | tiarei
# Processing Record 25 of Set 5 | lebu
# Processing Record 26 of Set 5 | dwarka
# Processing Record 27 of Set 5 | tarnow
# Processing Record 28 of Set 5 | boyolangu
# Processing Record 29 of Set 5 | saint anthony
# Processing Record 30 of Set 5 | puerto del rosario
# Processing Record 31 of Set 5 | hof
# Processing Record 32 of Set 5 | bud
# Processing Record 33 of Set 5 | biltine
# Processing Record 34 of Set 5 | loandjili
# Processing Record 35 of Set 5 | san angelo
# Processing Record 36 of Set 5 | cherskiy
# Processing Record 37 of Set 5 | adre
# Processing Record 38 of Set 5 | port alfred
# Processing Record 39 of Set 5 | port hardy
# Processing Record 40 of Set 5 | la ronge
# Processing Record 41 of Set 5 | copiapo
# Processing Record 42 of Set 5 | kavieng
# Processing Record 43 of Set 5 | fortuna
# Processing Record 44 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 45 of Set 5 | luderitz
# Processing Record 46 of Set 5 | setermoen
# Processing Record 47 of Set 5 | jabiru
# City not found. Skipping...
# Processing Record 48 of Set 5 | natal
# Processing Record 49 of Set 5 | columbia
# Processing Record 50 of Set 5 | jesus maria
# Processing Record 1 of Set 6 | bambous virieux
# Processing Record 2 of Set 6 | mackay
# Processing Record 3 of Set 6 | sorvag
# City not found. Skipping...
# Processing Record 4 of Set 6 | moranbah
# Processing Record 5 of Set 6 | boa vista
# Processing Record 6 of Set 6 | magadan
# Processing Record 7 of Set 6 | verdalsora
# City not found. Skipping...
# Processing Record 8 of Set 6 | namatanai
# Processing Record 9 of Set 6 | iranshahr
# Processing Record 10 of Set 6 | berlevag
# Processing Record 11 of Set 6 | rondonopolis
# Processing Record 12 of Set 6 | dores do indaia
# Processing Record 13 of Set 6 | velyka pysarivka
# Processing Record 14 of Set 6 | sangar
# Processing Record 15 of Set 6 | belaya gora
# Processing Record 16 of Set 6 | karratha
# Processing Record 17 of Set 6 | dingle
# Processing Record 18 of Set 6 | san cristobal
# Processing Record 19 of Set 6 | monrovia
# Processing Record 20 of Set 6 | katherine
# Processing Record 21 of Set 6 | bereda
# Processing Record 22 of Set 6 | wenling
# Processing Record 23 of Set 6 | duverge
# Processing Record 24 of Set 6 | winnemucca
# Processing Record 25 of Set 6 | arraial do cabo
# Processing Record 26 of Set 6 | kayankulam
# Processing Record 27 of Set 6 | korla
# Processing Record 28 of Set 6 | hami
# Processing Record 29 of Set 6 | san patricio
# Processing Record 30 of Set 6 | bom jesus
# Processing Record 31 of Set 6 | enderby
# Processing Record 32 of Set 6 | saint-pierre
# Processing Record 33 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 34 of Set 6 | taoudenni
# Processing Record 35 of Set 6 | itarema
# Processing Record 36 of Set 6 | montrose
# Processing Record 37 of Set 6 | ilulissat
# Processing Record 38 of Set 6 | chokurdakh
# Processing Record 39 of Set 6 | sisimiut
# Processing Record 40 of Set 6 | morehead
# Processing Record 41 of Set 6 | koumac
# Processing Record 42 of Set 6 | el ejido
# Processing Record 43 of Set 6 | shaartuz
# City not found. Skipping...
# Processing Record 44 of Set 6 | hella
# Processing Record 45 of Set 6 | tautira
# Processing Record 46 of Set 6 | mashhad
# Processing Record 47 of Set 6 | brigantine
# Processing Record 48 of Set 6 | general roca
# Processing Record 49 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 50 of Set 6 | abu dhabi
# Processing Record 1 of Set 7 | provideniya
# Processing Record 2 of Set 7 | saint george
# Processing Record 3 of Set 7 | pentecoste
# Processing Record 4 of Set 7 | severo-kurilsk
# Processing Record 5 of Set 7 | dubbo
# Processing Record 6 of Set 7 | rudnichnyy
# Processing Record 7 of Set 7 | mantua
# Processing Record 8 of Set 7 | trinidad
# Processing Record 9 of Set 7 | deputatskiy
# Processing Record 10 of Set 7 | kulhudhuffushi
# Processing Record 11 of Set 7 | coos bay
# Processing Record 12 of Set 7 | aklavik
# Processing Record 13 of Set 7 | truro
# Processing Record 14 of Set 7 | zyryanka
# Processing Record 15 of Set 7 | ostrovnoy
# Processing Record 16 of Set 7 | yanchukan
# City not found. Skipping...
# Processing Record 17 of Set 7 | bukachacha
# Processing Record 18 of Set 7 | valcourt
# Processing Record 19 of Set 7 | kassala
# Processing Record 20 of Set 7 | saint-joseph
# Processing Record 21 of Set 7 | rantauprapat
# Processing Record 22 of Set 7 | afgoye
# City not found. Skipping...
# Processing Record 23 of Set 7 | katsuura
# Processing Record 24 of Set 7 | ust-nera
# Processing Record 25 of Set 7 | chuy
# Processing Record 26 of Set 7 | abiy adi
# City not found. Skipping...
# Processing Record 27 of Set 7 | rapid valley
# Processing Record 28 of Set 7 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 29 of Set 7 | abu kamal
# Processing Record 30 of Set 7 | lavrentiya
# Processing Record 31 of Set 7 | yuncheng
# Processing Record 32 of Set 7 | calama
# Processing Record 33 of Set 7 | vagay
# Processing Record 34 of Set 7 | vredendal
# Processing Record 35 of Set 7 | chicama
# Processing Record 36 of Set 7 | guerrero negro
# Processing Record 37 of Set 7 | bat khela
# Processing Record 38 of Set 7 | davila
# Processing Record 39 of Set 7 | barreirinhas
# Processing Record 40 of Set 7 | charlestown
# Processing Record 41 of Set 7 | rungata
# City not found. Skipping...
# Processing Record 42 of Set 7 | sur
# Processing Record 43 of Set 7 | burica
# City not found. Skipping...
# Processing Record 44 of Set 7 | ayagoz
# Processing Record 45 of Set 7 | ambon
# Processing Record 46 of Set 7 | araxa
# Processing Record 47 of Set 7 | prado
# Processing Record 48 of Set 7 | yulara
# Processing Record 49 of Set 7 | padang
# Processing Record 50 of Set 7 | chumikan
# Processing Record 1 of Set 8 | anadyr
# Processing Record 2 of Set 8 | matara
# Processing Record 3 of Set 8 | juneau
# Processing Record 4 of Set 8 | melita
# Processing Record 5 of Set 8 | beyneu
# Processing Record 6 of Set 8 | orangeburg
# Processing Record 7 of Set 8 | verkhoyansk
# Processing Record 8 of Set 8 | coari
# Processing Record 9 of Set 8 | kefamenanu
# Processing Record 10 of Set 8 | trairi
# Processing Record 11 of Set 8 | harper
# Processing Record 12 of Set 8 | saint-paul
# Processing Record 13 of Set 8 | bundaberg
# Processing Record 14 of Set 8 | terre haute
# Processing Record 15 of Set 8 | wanning
# Processing Record 16 of Set 8 | carlagan
# Processing Record 17 of Set 8 | nome
# Processing Record 18 of Set 8 | ouro preto do oeste
# Processing Record 19 of Set 8 | sobolevo
# Processing Record 20 of Set 8 | jieshi
# Processing Record 21 of Set 8 | saint-leu
# Processing Record 22 of Set 8 | japura
# Processing Record 23 of Set 8 | klaksvik
# Processing Record 24 of Set 8 | manoel urbano
# Processing Record 25 of Set 8 | benghazi
# Processing Record 26 of Set 8 | acarau
# Processing Record 27 of Set 8 | grindavik
# Processing Record 28 of Set 8 | holbeach
# Processing Record 29 of Set 8 | carutapera
# Processing Record 30 of Set 8 | batagay-alyta
# Processing Record 31 of Set 8 | huancabamba
# Processing Record 32 of Set 8 | okato
# Processing Record 33 of Set 8 | okhotsk
# Processing Record 34 of Set 8 | rognan
# Processing Record 35 of Set 8 | ust-kuyga
# Processing Record 36 of Set 8 | turukhansk
# Processing Record 37 of Set 8 | chapais
# Processing Record 38 of Set 8 | jalu
# Processing Record 39 of Set 8 | saint-francois
# Processing Record 40 of Set 8 | honiara
# Processing Record 41 of Set 8 | northam
# Processing Record 42 of Set 8 | nioro
# Processing Record 43 of Set 8 | soe
# Processing Record 44 of Set 8 | hare bay
# Processing Record 45 of Set 8 | arawa
# Processing Record 46 of Set 8 | airai
# Processing Record 47 of Set 8 | longyearbyen
# Processing Record 48 of Set 8 | bargal
# City not found. Skipping...
# Processing Record 49 of Set 8 | belmonte
# Processing Record 50 of Set 8 | mount gambier
# Processing Record 1 of Set 9 | anzoategui
# Processing Record 2 of Set 9 | floro
# Processing Record 3 of Set 9 | conceicao do araguaia
# Processing Record 4 of Set 9 | ladario
# Processing Record 5 of Set 9 | hobyo
# Processing Record 6 of Set 9 | dingtao
# Processing Record 7 of Set 9 | svetlogorsk
# Processing Record 8 of Set 9 | dabwali
# Processing Record 9 of Set 9 | sitka
# Processing Record 10 of Set 9 | mahanoro
# Processing Record 11 of Set 9 | komsomolskiy
# Processing Record 12 of Set 9 | oranjemund
# Processing Record 13 of Set 9 | marsa matruh
# Processing Record 14 of Set 9 | talcahuano
# Processing Record 15 of Set 9 | aksu
# Processing Record 16 of Set 9 | kruisfontein
# Processing Record 17 of Set 9 | margate
# Processing Record 18 of Set 9 | zhuanghe
# Processing Record 19 of Set 9 | mys shmidta
# City not found. Skipping...
# Processing Record 20 of Set 9 | vegachi
# Processing Record 21 of Set 9 | zhigansk
# Processing Record 22 of Set 9 | muroto
# Processing Record 23 of Set 9 | emerald
# Processing Record 24 of Set 9 | sinnamary
# Processing Record 25 of Set 9 | half moon bay
# Processing Record 26 of Set 9 | dmitriyevskaya
# Processing Record 27 of Set 9 | anshun
# Processing Record 28 of Set 9 | maragogi
# Processing Record 29 of Set 9 | sao filipe
# Processing Record 30 of Set 9 | yashkul
# Processing Record 31 of Set 9 | lovington
# Processing Record 32 of Set 9 | gadung
# Processing Record 33 of Set 9 | vallenar
# Processing Record 34 of Set 9 | port moresby
# Processing Record 35 of Set 9 | pitimbu
# Processing Record 36 of Set 9 | warrensburg
# Processing Record 37 of Set 9 | port hedland
# Processing Record 38 of Set 9 | thanh hoa
# Processing Record 39 of Set 9 | bonthe
# Processing Record 40 of Set 9 | mayo
# Processing Record 41 of Set 9 | slave lake
# Processing Record 42 of Set 9 | amarante do maranhao
# Processing Record 43 of Set 9 | kippen
# Processing Record 44 of Set 9 | povoa de santa iria
# Processing Record 45 of Set 9 | muncar
# Processing Record 46 of Set 9 | riyadh
# Processing Record 47 of Set 9 | castanos
# Processing Record 48 of Set 9 | mananjary
# Processing Record 49 of Set 9 | wau
# Processing Record 50 of Set 9 | rio cuarto
# Processing Record 1 of Set 10 | phrai bung
# City not found. Skipping...
# Processing Record 2 of Set 10 | birjand
# Processing Record 3 of Set 10 | namibe
# Processing Record 4 of Set 10 | praia
# Processing Record 5 of Set 10 | inhambane
# Processing Record 6 of Set 10 | akureyri
# Processing Record 7 of Set 10 | broken hill
# Processing Record 8 of Set 10 | caldwell
# Processing Record 9 of Set 10 | ormara
# Processing Record 10 of Set 10 | pine bluff
# Processing Record 11 of Set 10 | lakes entrance
# Processing Record 12 of Set 10 | itamaraca
# Processing Record 13 of Set 10 | cabedelo
# Processing Record 14 of Set 10 | comodoro rivadavia
# Processing Record 15 of Set 10 | rafaela
# Processing Record 16 of Set 10 | celestun
# Processing Record 17 of Set 10 | santa isabel do rio negro
# Processing Record 18 of Set 10 | axim
# Processing Record 19 of Set 10 | vanimo
# Processing Record 20 of Set 10 | drimmelen
# Processing Record 21 of Set 10 | segezha
# Processing Record 22 of Set 10 | shingu
# Processing Record 23 of Set 10 | mae sai
# Processing Record 24 of Set 10 | skjervoy
# Processing Record 25 of Set 10 | kamenka
# Processing Record 26 of Set 10 | alofi
# Processing Record 27 of Set 10 | pahrump
# Processing Record 28 of Set 10 | virginia beach
# Processing Record 29 of Set 10 | mullaitivu
# City not found. Skipping...
# Processing Record 30 of Set 10 | bumba
# Processing Record 31 of Set 10 | tabou
# Processing Record 32 of Set 10 | buchanan
# Processing Record 33 of Set 10 | puerto ayacucho
# Processing Record 34 of Set 10 | luba
# Processing Record 35 of Set 10 | espanola
# Processing Record 36 of Set 10 | omboue
# Processing Record 37 of Set 10 | ekhabi
# Processing Record 38 of Set 10 | hokitika
# Processing Record 39 of Set 10 | srednekolymsk
# Processing Record 40 of Set 10 | dinsor
# City not found. Skipping...
# Processing Record 41 of Set 10 | suhut
# Processing Record 42 of Set 10 | puerto asis
# Processing Record 43 of Set 10 | uk
# City not found. Skipping...
# Processing Record 44 of Set 10 | malaya serdoba
# Processing Record 45 of Set 10 | sungaipenuh
# Processing Record 46 of Set 10 | algiers
# Processing Record 47 of Set 10 | rudnogorsk
# Processing Record 48 of Set 10 | sibenik
# Processing Record 49 of Set 10 | bathsheba
# Processing Record 50 of Set 10 | kinablangan
# Processing Record 1 of Set 11 | nemuro
# Processing Record 2 of Set 11 | poum
# Processing Record 3 of Set 11 | bambanglipuro
# Processing Record 4 of Set 11 | lixourion
# Processing Record 5 of Set 11 | mount isa
# Processing Record 6 of Set 11 | birao
# Processing Record 7 of Set 11 | iralaya
# Processing Record 8 of Set 11 | mikhaylovskoye
# Processing Record 9 of Set 11 | danville
# Processing Record 10 of Set 11 | zhezkazgan
# Processing Record 11 of Set 11 | xining
# Processing Record 12 of Set 11 | lompoc
# Processing Record 13 of Set 11 | raudeberg
# Processing Record 14 of Set 11 | clarence town
# Processing Record 15 of Set 11 | kushmurun
# Processing Record 16 of Set 11 | grand baie
# Processing Record 17 of Set 11 | sirfa
# City not found. Skipping...
# Processing Record 18 of Set 11 | yenagoa
# Processing Record 19 of Set 11 | emba
# Processing Record 20 of Set 11 | yaan
# Processing Record 21 of Set 11 | lasa
# Processing Record 22 of Set 11 | ornskoldsvik
# Processing Record 23 of Set 11 | yorosso
# Processing Record 24 of Set 11 | vila franca do campo
# Processing Record 25 of Set 11 | ilo
# Processing Record 26 of Set 11 | puerto penasco
# Processing Record 27 of Set 11 | fairbanks
# Processing Record 28 of Set 11 | henties bay
# Processing Record 29 of Set 11 | holme
# Processing Record 30 of Set 11 | santarem
# Processing Record 31 of Set 11 | izumo
# Processing Record 32 of Set 11 | kilindoni
# Processing Record 33 of Set 11 | contamana
# Processing Record 34 of Set 11 | avera
# Processing Record 35 of Set 11 | moscow
# Processing Record 36 of Set 11 | kasongo-lunda
# Processing Record 37 of Set 11 | tilichiki
# Processing Record 38 of Set 11 | cape canaveral
# Processing Record 39 of Set 11 | bentiu
# Processing Record 40 of Set 11 | olafsvik
# Processing Record 41 of Set 11 | acapulco
# Processing Record 42 of Set 11 | rio claro
# Processing Record 43 of Set 11 | moose factory
# Processing Record 44 of Set 11 | manokwari
# Processing Record 45 of Set 11 | chara
# Processing Record 46 of Set 11 | wonthaggi
# Processing Record 47 of Set 11 | athabasca
# Processing Record 48 of Set 11 | pevek
# Processing Record 49 of Set 11 | erdenet
# Processing Record 50 of Set 11 | nikolayevka
# Processing Record 1 of Set 12 | vestmanna
# Processing Record 2 of Set 12 | tumannyy
# City not found. Skipping...
# Processing Record 3 of Set 12 | flinders
# Processing Record 4 of Set 12 | macau
# Processing Record 5 of Set 12 | iquique
# Processing Record 6 of Set 12 | ozinki
# Processing Record 7 of Set 12 | amelia
# Processing Record 8 of Set 12 | roald
# Processing Record 9 of Set 12 | atasu
# Processing Record 10 of Set 12 | sayyan
# Processing Record 11 of Set 12 | halifax
# Processing Record 12 of Set 12 | kudahuvadhoo
# Processing Record 13 of Set 12 | wewak
# Processing Record 14 of Set 12 | hudson bay
# Processing Record 15 of Set 12 | saint charles
# Processing Record 16 of Set 12 | mardin
# Processing Record 17 of Set 12 | villamontes
# Processing Record 18 of Set 12 | thio
# Processing Record 19 of Set 12 | ippy
# Processing Record 20 of Set 12 | skowhegan
# Processing Record 21 of Set 12 | haines junction
# Processing Record 22 of Set 12 | cascais
# Processing Record 23 of Set 12 | madimba
# Processing Record 24 of Set 12 | antofagasta
# Processing Record 25 of Set 12 | temuco
# Processing Record 26 of Set 12 | george
# Processing Record 27 of Set 12 | kavaratti
# Processing Record 28 of Set 12 | astorga
# Processing Record 29 of Set 12 | serafimovich
# Processing Record 30 of Set 12 | ola
# Processing Record 31 of Set 12 | high level
# Processing Record 32 of Set 12 | chopovychi
# Processing Record 33 of Set 12 | makat
# Processing Record 34 of Set 12 | tankara
# Processing Record 35 of Set 12 | igarka
# Processing Record 36 of Set 12 | kuopio
# Processing Record 37 of Set 12 | montelibano
# Processing Record 38 of Set 12 | charyshskoye
# Processing Record 39 of Set 12 | nieuw amsterdam
# Processing Record 40 of Set 12 | kaka
# Processing Record 41 of Set 12 | tieli
# Processing Record 42 of Set 12 | porto walter
# Processing Record 43 of Set 12 | maniitsoq
# Processing Record 44 of Set 12 | mezen
# Processing Record 45 of Set 12 | samfya
# Processing Record 46 of Set 12 | mbamba
# Processing Record 47 of Set 12 | taltal
# Processing Record 48 of Set 12 | notse
# Processing Record 49 of Set 12 | chaman
# Processing Record 50 of Set 12 | roches noires
# City not found. Skipping...
# Processing Record 1 of Set 13 | tromso
# Processing Record 2 of Set 13 | benguela
# Processing Record 3 of Set 13 | kargil
# Processing Record 4 of Set 13 | nuuk
# Processing Record 5 of Set 13 | marcona
# City not found. Skipping...
# Processing Record 6 of Set 13 | la macarena
# Processing Record 7 of Set 13 | los llanos de aridane
# Processing Record 8 of Set 13 | nizhneangarsk
# Processing Record 9 of Set 13 | babu
# Processing Record 10 of Set 13 | cap malheureux
# Processing Record 11 of Set 13 | basse
# Processing Record 12 of Set 13 | ormos korthiou
# City not found. Skipping...
# Processing Record 13 of Set 13 | yumen
# Processing Record 14 of Set 13 | qandala
# Processing Record 15 of Set 13 | katobu
# Processing Record 16 of Set 13 | hauterive
# Processing Record 17 of Set 13 | suez
# Processing Record 18 of Set 13 | sault sainte marie
# Processing Record 19 of Set 13 | kirovskiy
# Processing Record 20 of Set 13 | rocha
# Processing Record 21 of Set 13 | along
# Processing Record 22 of Set 13 | suhbaatar
# Processing Record 23 of Set 13 | goderich
# Processing Record 24 of Set 13 | cananea
# Processing Record 25 of Set 13 | kobryn
# Processing Record 26 of Set 13 | jiaonan
# Processing Record 27 of Set 13 | bacum
# Processing Record 28 of Set 13 | punta cardon
# Processing Record 29 of Set 13 | kamenskoye
# City not found. Skipping...
# Processing Record 30 of Set 13 | bristol
# Processing Record 31 of Set 13 | adrar
# Processing Record 32 of Set 13 | merauke
# Processing Record 33 of Set 13 | kaliganj
# Processing Record 34 of Set 13 | ballina
# Processing Record 35 of Set 13 | orizona
# Processing Record 36 of Set 13 | volchansk
# Processing Record 37 of Set 13 | castelnaudary
# Processing Record 38 of Set 13 | rawannawi
# City not found. Skipping...
# Processing Record 39 of Set 13 | ardesen
# Processing Record 40 of Set 13 | kirov
# Processing Record 41 of Set 13 | zapolyarnyy
# Processing Record 42 of Set 13 | karachi
# Processing Record 43 of Set 13 | vestmannaeyjar
# Processing Record 44 of Set 13 | orange cove
# Processing Record 45 of Set 13 | barawe
# City not found. Skipping...
# Processing Record 46 of Set 13 | barguzin
# Processing Record 47 of Set 13 | uvinza
# Processing Record 48 of Set 13 | zhaotong
# Processing Record 49 of Set 13 | monster
# Processing Record 50 of Set 13 | satitoa
# City not found. Skipping...
# Processing Record 1 of Set 14 | havoysund
# Processing Record 2 of Set 14 | keetmanshoop
# Processing Record 3 of Set 14 | shelopugino
# Processing Record 4 of Set 14 | san quintin
# Processing Record 5 of Set 14 | vostok
# Processing Record 6 of Set 14 | tucuman
# Processing Record 7 of Set 14 | sorland
# Processing Record 8 of Set 14 | nouadhibou
# Processing Record 9 of Set 14 | hualmay
# Processing Record 10 of Set 14 | raga
# Processing Record 11 of Set 14 | iglesias
# Processing Record 12 of Set 14 | cortez
# Processing Record 13 of Set 14 | nizhnevartovsk
# Processing Record 14 of Set 14 | marsh harbour
# Processing Record 15 of Set 14 | malm
# Processing Record 16 of Set 14 | tapaua
# City not found. Skipping...
# Processing Record 17 of Set 14 | vila do maio
# Processing Record 18 of Set 14 | staraya russa
# Processing Record 19 of Set 14 | teya
# Processing Record 20 of Set 14 | pitea
# Processing Record 21 of Set 14 | port blair
# Processing Record 22 of Set 14 | treinta y tres
# Processing Record 23 of Set 14 | bacolod
# Processing Record 24 of Set 14 | kuytun
# Processing Record 25 of Set 14 | walvis bay
# Processing Record 26 of Set 14 | saint-georges
# Processing Record 27 of Set 14 | akyab
# Processing Record 28 of Set 14 | hay river
# Processing Record 29 of Set 14 | bardiyah
# Processing Record 30 of Set 14 | pereira barreto
# Processing Record 31 of Set 14 | ponta delgada
# Processing Record 32 of Set 14 | berdsk
# Processing Record 33 of Set 14 | ulladulla
# Processing Record 34 of Set 14 | praia da vitoria
# Processing Record 35 of Set 14 | bolshegrivskoye
# City not found. Skipping...
# Processing Record 36 of Set 14 | kaeo
# Processing Record 37 of Set 14 | bandarbeyla
# Processing Record 38 of Set 14 | umm durman
# City not found. Skipping...
# Processing Record 39 of Set 14 | budogoshch
# Processing Record 40 of Set 14 | skibbereen
# Processing Record 41 of Set 14 | louisbourg
# City not found. Skipping...
# Processing Record 42 of Set 14 | piacabucu
# Processing Record 43 of Set 14 | bone
# Processing Record 44 of Set 14 | koboko
# Processing Record 45 of Set 14 | liku
# Processing Record 46 of Set 14 | bogorodskoye
# Processing Record 47 of Set 14 | kahului
# Processing Record 48 of Set 14 | sabibah
# City not found. Skipping...
# Processing Record 49 of Set 14 | suslovo
# Processing Record 50 of Set 14 | lagoa
# Processing Record 1 of Set 15 | saint simons
# Processing Record 2 of Set 15 | kibala
# Processing Record 3 of Set 15 | angra
# City not found. Skipping...
# Processing Record 4 of Set 15 | verkhnyaya toyma
# Processing Record 5 of Set 15 | aguas de lindoia
# Processing Record 6 of Set 15 | iaciara
# Processing Record 7 of Set 15 | ciudad bolivar
# Processing Record 8 of Set 15 | yatou
# Processing Record 9 of Set 15 | marzuq
# Processing Record 10 of Set 15 | edd
# Processing Record 11 of Set 15 | ulsteinvik
# Processing Record 12 of Set 15 | chandpur
# Processing Record 13 of Set 15 | mocuba
# Processing Record 14 of Set 15 | werda
# Processing Record 15 of Set 15 | venado tuerto
# Processing Record 16 of Set 15 | tongchuan
# Processing Record 17 of Set 15 | marystown
# Processing Record 18 of Set 15 | barranco
# Processing Record 19 of Set 15 | elizabeth city
# Processing Record 20 of Set 15 | vuktyl
# Processing Record 21 of Set 15 | san nicolas
# Processing Record 22 of Set 15 | laguna
# Processing Record 23 of Set 15 | neuquen
# Processing Record 24 of Set 15 | kungurtug
# Processing Record 25 of Set 15 | macaboboni
# City not found. Skipping...
# Processing Record 26 of Set 15 | naze
# Processing Record 27 of Set 15 | buraydah
# Processing Record 28 of Set 15 | mahajanga
# Processing Record 29 of Set 15 | mayumba
# Processing Record 30 of Set 15 | khonsa
# Processing Record 31 of Set 15 | ayia galini
# Processing Record 32 of Set 15 | lola
# Processing Record 33 of Set 15 | straumen
# Processing Record 34 of Set 15 | antalaha
# Processing Record 35 of Set 15 | ramgarh
# Processing Record 36 of Set 15 | baykit
# Processing Record 37 of Set 15 | rio negrinho
# Processing Record 38 of Set 15 | kuminskiy
# Processing Record 39 of Set 15 | hvolsvollur
# Processing Record 40 of Set 15 | khorramshahr
# Processing Record 41 of Set 15 | lamu
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data
# Out:
# [{'City': 'Rio Gallegos',
#   'Lat': -51.6226,
#   'Lng': -69.2181,
#   'Max Temp': 35.65,
#   'Humidity': 69,
#   'Cloudiness': 0,
#   'Wind Speed': 11.5,
#   'Country': 'AR',
#   'Date': '2021-06-06 06:21:27',
#   'Current Description': 'clear sky'},
#  {'City': 'Rikitea',
#   'Lat': -23.1203,
#   'Lng': -134.9692,
#   'Max Temp': 76.05,
#   'Humidity': 83,
#   'Cloudiness': 72,
#   'Wind Speed': 15.9,
#   'Country': 'PF',
#   'Date': '2021-06-06 06:21:49',
#   'Current Description': 'light rain'},
#  {'City': 'Suntar',
#   'Lat': 62.1444,
#   'Lng': 117.6319,
#   'Max Temp': 52.77,
#   'Humidity': 73,
#   'Cloudiness': 100,
#   'Wind Speed': 2.91,
#   'Country': 'RU',
#   'Date': '2021-06-06 06:21:49',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Bethel',
#   'Lat': 41.3712,
#   'Lng': -73.414,
#   'Max Temp': 76.19,
#   'Humidity': 73,
#   'Cloudiness': 1,
#   'Wind Speed': 0,
#   'Country': 'US',
#   'Date': '2021-06-06 06:21:49',
#   'Current Description': 'clear sky'},
#  {'City': 'Ancud',
#   'Lat': -41.8697,
#   'Lng': -73.8203,
#   'Max Temp': 46.22,
#   'Humidity': 83,
#   'Cloudiness': 96,
#   'Wind Speed': 4.76,
#   'Country': 'CL',
#   'Date': '2021-06-06 06:21:50',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Samarai',
#   'Lat': -10.6167,
#   'Lng': 150.6667,
#   'Max Temp': 78.33,
#   'Humidity': 87,
#   'Cloudiness': 94,
#   'Wind Speed': 16.28,
#   'Country': 'PG',
#   'Date': '2021-06-06 06:21:50',
#   'Current Description': 'light rain'},
#  {'City': 'Darlowo',
#   'Lat': 54.421,
#   'Lng': 16.4107,
#   'Max Temp': 60.94,
#   'Humidity': 65,
#   'Cloudiness': 13,
#   'Wind Speed': 4.05,
#   'Country': 'PL',
#   'Date': '2021-06-06 06:21:50',
#   'Current Description': 'few clouds'},
#  {'City': 'Upernavik',
#   'Lat': 72.7868,
#   'Lng': -56.1549,
#   'Max Temp': 33.51,
#   'Humidity': 83,
#   'Cloudiness': 2,
#   'Wind Speed': 3.13,
#   'Country': 'GL',
#   'Date': '2021-06-06 06:21:51',
#   'Current Description': 'clear sky'},
#  {'City': 'Soubre',
#   'Lat': 5.7856,
#   'Lng': -6.6083,
#   'Max Temp': 71.96,
#   'Humidity': 99,
#   'Cloudiness': 74,
#   'Wind Speed': 2.08,
#   'Country': 'CI',
#   'Date': '2021-06-06 06:21:52',
#   'Current Description': 'broken clouds'},
#  {'City': 'Nishihara',
#   'Lat': 26.1842,
#   'Lng': 127.7558,
#   'Max Temp': 85.66,
#   'Humidity': 76,
#   'Cloudiness': 75,
#   'Wind Speed': 17.76,
#   'Country': 'JP',
#   'Date': '2021-06-06 06:21:53',
#   'Current Description': 'broken clouds'},
#  {'City': 'Buenos Aires',
#   'Lat': -34.6132,
#   'Lng': -58.3772,
#   'Max Temp': 49.73,
#   'Humidity': 61,
#   'Cloudiness': 0,
#   'Wind Speed': 5.75,
#   'Country': 'AR',
#   'Date': '2021-06-06 06:21:42',
#   'Current Description': 'clear sky'},
#  {'City': 'Mataura',
#   'Lat': -46.1927,
#   'Lng': 168.8643,
#   'Max Temp': 49.48,
#   'Humidity': 95,
#   'Cloudiness': 29,
#   'Wind Speed': 0.54,
#   'Country': 'NZ',
#   'Date': '2021-06-06 06:21:54',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Saskylakh',
#   'Lat': 71.9167,
#   'Lng': 114.0833,
#   'Max Temp': 46,
#   'Humidity': 42,
#   'Cloudiness': 87,
#   'Wind Speed': 12.1,
#   'Country': 'RU',
#   'Date': '2021-06-06 06:21:54',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Punta Arenas',
#   'Lat': -53.15,
#   'Lng': -70.9167,
#   'Max Temp': 37.51,
#   'Humidity': 81,
#   'Cloudiness': 90,
#   'Wind Speed': 13.91,
#   'Country': 'CL',
#   'Date': '2021-06-06 06:21:55',
#   'Current Description': 'light rain'},
#  {'City': 'Yellowknife',
#   'Lat': 62.456,
#   'Lng': -114.3525,
#   'Max Temp': 51.3,
#   'Humidity': 62,
#   'Cloudiness': 20,
#   'Wind Speed': 8.01,
#   'Country': 'CA',
#   'Date': '2021-06-06 06:21:02',
#   'Current Description': 'few clouds'},
#  {'City': 'Banepa',
#   'Lat': 27.6298,
#   'Lng': 85.5214,
#   'Max Temp': 80.92,
#   'Humidity': 57,
#   'Cloudiness': 40,
#   'Wind Speed': 5.06,
#   'Country': 'NP',
#   'Date': '2021-06-06 06:17:11',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Golitsyno',
#   'Lat': 55.6122,
#   'Lng': 36.9833,
#   'Max Temp': 68.07,
#   'Humidity': 59,
#   'Cloudiness': 20,
#   'Wind Speed': 8.55,
#   'Country': 'RU',
#   'Date': '2021-06-06 06:21:56',
#   'Current Description': 'few clouds'},
#  {'City': 'Touros',
#   'Lat': -5.1989,
#   'Lng': -35.4608,
#   'Max Temp': 74.3,
#   'Humidity': 91,
#   'Cloudiness': 52,
#   'Wind Speed': 11.23,
#   'Country': 'BR',
#   'Date': '2021-06-06 06:21:56',
#   'Current Description': 'broken clouds'},
#  {'City': 'Ushuaia',
#   'Lat': -54.8,
#   'Lng': -68.3,
#   'Max Temp': 31.66,
#   'Humidity': 93,
#   'Cloudiness': 0,
#   'Wind Speed': 3.44,
#   'Country': 'AR',
#   'Date': '2021-06-06 06:21:47',
#   'Current Description': 'clear sky'},
#  {'City': 'Kapaa',
#   'Lat': 22.0752,
#   'Lng': -159.319,
#   'Max Temp': 77.32,
#   'Humidity': 76,
#   'Cloudiness': 40,
#   'Wind Speed': 1.99,
#   'Country': 'US',
#   'Date': '2021-06-06 06:20:35',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Saint-Philippe',
#   'Lat': -21.3585,
#   'Lng': 55.7679,
#   'Max Temp': 79.21,
#   'Humidity': 80,
#   'Cloudiness': 60,
#   'Wind Speed': 2.53,
#   'Country': 'RE',
#   'Date': '2021-06-06 06:21:57',
#   'Current Description': 'light rain'},
#  {'City': 'Victoria',
#   'Lat': 22.2855,
#   'Lng': 114.1577,
#   'Max Temp': 87.96,
#   'Humidity': 69,
#   'Cloudiness': 30,
#   'Wind Speed': 1.01,
#   'Country': 'HK',
#   'Date': '2021-06-06 06:21:17',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Ayapel',
#   'Lat': 8.3137,
#   'Lng': -75.1398,
#   'Max Temp': 75.07,
#   'Humidity': 96,
#   'Cloudiness': 98,
#   'Wind Speed': 2.37,
#   'Country': 'CO',
#   'Date': '2021-06-06 06:21:58',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Fort Nelson',
#   'Lat': 58.8053,
#   'Lng': -122.7002,
#   'Max Temp': 51.39,
#   'Humidity': 93,
#   'Cloudiness': 75,
#   'Wind Speed': 4.61,
#   'Country': 'CA',
#   'Date': '2021-06-06 06:21:58',
#   'Current Description': 'light rain'},
#  {'City': 'Hermanus',
#   'Lat': -34.4187,
#   'Lng': 19.2345,
#   'Max Temp': 58.95,
#   'Humidity': 39,
#   'Cloudiness': 22,
#   'Wind Speed': 9.17,
#   'Country': 'ZA',
#   'Date': '2021-06-06 06:21:58',
#   'Current Description': 'few clouds'},
#  {'City': 'Linjiang',
#   'Lat': 41.8069,
#   'Lng': 126.9078,
#   'Max Temp': 69.66,
#   'Humidity': 58,
#   'Cloudiness': 84,
#   'Wind Speed': 5.32,
#   'Country': 'CN',
#   'Date': '2021-06-06 06:21:59',
#   'Current Description': 'moderate rain'},
#  {'City': 'Mangrol',
#   'Lat': 21.1167,
#   'Lng': 70.1167,
#   'Max Temp': 89.2,
#   'Humidity': 56,
#   'Cloudiness': 5,
#   'Wind Speed': 10.69,
#   'Country': 'IN',
#   'Date': '2021-06-06 06:21:59',
#   'Current Description': 'clear sky'},
#  {'City': 'Salalah',
#   'Lat': 17.0151,
#   'Lng': 54.0924,
#   'Max Temp': 89.69,
#   'Humidity': 66,
#   'Cloudiness': 40,
#   'Wind Speed': 9.22,
#   'Country': 'OM',
#   'Date': '2021-06-06 06:21:13',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Cabra',
#   'Lat': 37.4725,
#   'Lng': -4.4421,
#   'Max Temp': 66.9,
#   'Humidity': 71,
#   'Cloudiness': 0,
#   'Wind Speed': 3.15,
#   'Country': 'ES',
#   'Date': '2021-06-06 06:22:00',
#   'Current Description': 'clear sky'},
#  {'City': 'Castro',
#   'Lat': -24.7911,
#   'Lng': -50.0119,
#   'Max Temp': 57.61,
#   'Humidity': 72,
#   'Cloudiness': 64,
#   'Wind Speed': 2.48,
#   'Country': 'BR',
#   'Date': '2021-06-06 06:22:00',
#   'Current Description': 'broken clouds'},
#  {'City': 'Bengkulu',
#   'Lat': -3.8004,
#   'Lng': 102.2655,
#   'Max Temp': 84.31,
#   'Humidity': 67,
#   'Cloudiness': 14,
#   'Wind Speed': 6.8,
#   'Country': 'ID',
#   'Date': '2021-06-06 06:22:01',
#   'Current Description': 'few clouds'},
#  {'City': 'Grand Gaube',
#   'Lat': -20.0064,
#   'Lng': 57.6608,
#   'Max Temp': 79.38,
#   'Humidity': 73,
#   'Cloudiness': 70,
#   'Wind Speed': 1.99,
#   'Country': 'MU',
#   'Date': '2021-06-06 06:22:01',
#   'Current Description': 'broken clouds'},
#  {'City': 'Seoul',
#   'Lat': 37.5683,
#   'Lng': 126.9778,
#   'Max Temp': 84.61,
#   'Humidity': 47,
#   'Cloudiness': 20,
#   'Wind Speed': 8.68,
#   'Country': 'KR',
#   'Date': '2021-06-06 06:20:00',
#   'Current Description': 'few clouds'},
#  {'City': 'Najran',
#   'Lat': 17.4924,
#   'Lng': 44.1277,
#   'Max Temp': 93.85,
#   'Humidity': 13,
#   'Cloudiness': 0,
#   'Wind Speed': 1.36,
#   'Country': 'SA',
#   'Date': '2021-06-06 06:22:02',
#   'Current Description': 'clear sky'},
#  {'City': 'Butaritari',
#   'Lat': 3.0707,
#   'Lng': 172.7902,
#   'Max Temp': 83.08,
#   'Humidity': 73,
#   'Cloudiness': 24,
#   'Wind Speed': 6.6,
#   'Country': 'KI',
#   'Date': '2021-06-06 06:22:02',
#   'Current Description': 'light rain'},
#  {'City': 'Pilar',
#   'Lat': -9.5972,
#   'Lng': -35.9567,
#   'Max Temp': 69.73,
#   'Humidity': 94,
#   'Cloudiness': 22,
#   'Wind Speed': 1.03,
#   'Country': 'BR',
#   'Date': '2021-06-06 06:22:03',
#   'Current Description': 'few clouds'},
#  {'City': 'Balkanabat',
#   'Lat': 39.5108,
#   'Lng': 54.3671,
#   'Max Temp': 80.22,
#   'Humidity': 47,
#   'Cloudiness': 6,
#   'Wind Speed': 12.21,
#   'Country': 'TM',
#   'Date': '2021-06-06 06:22:03',
#   'Current Description': 'clear sky'},
#  {'City': 'Torbay',
#   'Lat': 47.6666,
#   'Lng': -52.7314,
#   'Max Temp': 54.88,
#   'Humidity': 98,
#   'Cloudiness': 90,
#   'Wind Speed': 17.27,
#   'Country': 'CA',
#   'Date': '2021-06-06 06:22:03',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Busselton',
#   'Lat': -33.65,
#   'Lng': 115.3333,
#   'Max Temp': 64.04,
#   'Humidity': 57,
#   'Cloudiness': 74,
#   'Wind Speed': 16.75,
#   'Country': 'AU',
#   'Date': '2021-06-06 06:22:04',
#   'Current Description': 'broken clouds'},
#  {'City': 'New Norfolk',
#   'Lat': -42.7826,
#   'Lng': 147.0587,
#   'Max Temp': 51.93,
#   'Humidity': 58,
#   'Cloudiness': 100,
#   'Wind Speed': 4.52,
#   'Country': 'AU',
#   'Date': '2021-06-06 06:22:04',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Xichang',
#   'Lat': 27.8964,
#   'Lng': 102.2634,
#   'Max Temp': 69.01,
#   'Humidity': 79,
#   'Cloudiness': 99,
#   'Wind Speed': 0.27,
#   'Country': 'CN',
#   'Date': '2021-06-06 06:22:05',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Ouadda',
#   'Lat': 8.0777,
#   'Lng': 22.4007,
#   'Max Temp': 67.41,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 6.11,
#   'Country': 'CF',
#   'Date': '2021-06-06 06:22:05',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Tuktoyaktuk',
#   'Lat': 69.4541,
#   'Lng': -133.0374,
#   'Max Temp': 33.64,
#   'Humidity': 83,
#   'Cloudiness': 18,
#   'Wind Speed': 8.99,
#   'Country': 'CA',
#   'Date': '2021-06-06 06:22:06',
#   'Current Description': 'few clouds'},
#  {'City': 'Kamaishi',
#   'Lat': 39.2667,
#   'Lng': 141.8833,
#   'Max Temp': 83.35,
#   'Humidity': 64,
#   'Cloudiness': 87,
#   'Wind Speed': 11.1,
#   'Country': 'JP',
#   'Date': '2021-06-06 06:22:06',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Viedma',
#   'Lat': -40.8135,
#   'Lng': -62.9967,
#   'Max Temp': 44.83,
#   'Humidity': 55,
#   'Cloudiness': 0,
#   'Wind Speed': 7.65,
#   'Country': 'AR',
#   'Date': '2021-06-06 06:22:07',
#   'Current Description': 'clear sky'},
#  {'City': 'San Policarpo',
#   'Lat': 12.1791,
#   'Lng': 125.5072,
#   'Max Temp': 84.31,
#   'Humidity': 74,
#   'Cloudiness': 74,
#   'Wind Speed': 1.5,
#   'Country': 'PH',
#   'Date': '2021-06-06 06:22:07',
#   'Current Description': 'broken clouds'},
#  {'City': 'Vaini',
#   'Lat': -21.2,
#   'Lng': -175.2,
#   'Max Temp': 71.76,
#   'Humidity': 88,
#   'Cloudiness': 75,
#   'Wind Speed': 0,
#   'Country': 'TO',
#   'Date': '2021-06-06 06:22:07',
#   'Current Description': 'broken clouds'},
#  {'City': 'Georgetown',
#   'Lat': 5.4112,
#   'Lng': 100.3354,
#   'Max Temp': 89.55,
#   'Humidity': 70,
#   'Cloudiness': 40,
#   'Wind Speed': 1.01,
#   'Country': 'MY',
#   'Date': '2021-06-06 06:22:08',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Arman',
#   'Lat': 59.7,
#   'Lng': 150.1667,
#   'Max Temp': 43.68,
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 3.91,
#   'Country': 'RU',
#   'Date': '2021-06-06 06:22:09',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Springfield',
#   'Lat': 37.2153,
#   'Lng': -93.2982,
#   'Max Temp': 69.03,
#   'Humidity': 92,
#   'Cloudiness': 1,
#   'Wind Speed': 5.99,
#   'Country': 'US',
#   'Date': '2021-06-06 06:17:22',
#   'Current Description': 'clear sky'},
#  {'City': 'Ambilobe',
#   'Lat': -13.2,
#   'Lng': 49.05,
#   'Max Temp': 81.43,
#   'Humidity': 64,
#   'Cloudiness': 62,
#   'Wind Speed': 3.47,
#   'Country': 'MG',
#   'Date': '2021-06-06 06:22:10',
#   'Current Description': 'broken clouds'},
#  {'City': 'Waingapu',
#   'Lat': -9.6567,
#   'Lng': 120.2641,
#   'Max Temp': 85.78,
#   'Humidity': 62,
#   'Cloudiness': 38,
#   'Wind Speed': 11.68,
#   'Country': 'ID',
#   'Date': '2021-06-06 06:22:10',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Mora',
#   'Lat': 11.0461,
#   'Lng': 14.1401,
#   'Max Temp': 85.01,
#   'Humidity': 46,
#   'Cloudiness': 92,
#   'Wind Speed': 6.58,
#   'Country': 'CM',
#   'Date': '2021-06-06 06:22:11',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Jamestown',
#   'Lat': 42.097,
#   'Lng': -79.2353,
#   'Max Temp': 69.39,
#   'Humidity': 80,
#   'Cloudiness': 1,
#   'Wind Speed': 1.99,
#   'Country': 'US',
#   'Date': '2021-06-06 06:22:11',
#   'Current Description': 'clear sky'},
#  {'City': 'Port Lincoln',
#   'Lat': -34.7333,
#   'Lng': 135.8667,
#   'Max Temp': 65.26,
#   'Humidity': 56,
#   'Cloudiness': 45,
#   'Wind Speed': 19.35,
#   'Country': 'AU',
#   'Date': '2021-06-06 06:22:11',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Norman Wells',
#   'Lat': 65.282,
#   'Lng': -126.8329,
#   'Max Temp': 44.64,
#   'Humidity': 81,
#   'Cloudiness': 90,
#   'Wind Speed': 13.8,
#   'Country': 'CA',
#   'Date': '2021-06-06 06:22:12',
#   'Current Description': 'light rain'},
#  {'City': 'Ribeira Grande',
#   'Lat': 38.5167,
#   'Lng': -28.7,
#   'Max Temp': 64.8,
#   'Humidity': 88,
#   'Cloudiness': 40,
#   'Wind Speed': 9.22,
#   'Country': 'PT',
#   'Date': '2021-06-06 06:22:12',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Isangel',
#   'Lat': -19.55,
#   'Lng': 169.2667,
#   'Max Temp': 77.11,
#   'Humidity': 65,
#   'Cloudiness': 75,
#   'Wind Speed': 15.93,
#   'Country': 'VU',
#   'Date': '2021-06-06 06:22:13',
#   'Current Description': 'broken clouds'},
#  {'City': 'Ahipara',
#   'Lat': -35.1667,
#   'Lng': 173.1667,
#   'Max Temp': 58.35,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 10.13,
#   'Country': 'NZ',
#   'Date': '2021-06-06 06:22:13',
#   'Current Description': 'light rain'},
#  {'City': 'Carnarvon',
#   'Lat': -24.8667,
#   'Lng': 113.6333,
#   'Max Temp': 73.47,
#   'Humidity': 60,
#   'Cloudiness': 90,
#   'Wind Speed': 12.66,
#   'Country': 'AU',
#   'Date': '2021-06-06 06:22:13',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Richards Bay',
#   'Lat': -28.783,
#   'Lng': 32.0377,
#   'Max Temp': 61.47,
#   'Humidity': 83,
#   'Cloudiness': 86,
#   'Wind Speed': 2.64,
#   'Country': 'ZA',
#   'Date': '2021-06-06 06:18:00',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Hasaki',
#   'Lat': 35.7333,
#   'Lng': 140.8333,
#   'Max Temp': 73.69,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 4.29,
#   'Country': 'JP',
#   'Date': '2021-06-06 06:22:15',
#   'Current Description': 'light rain'},
#  {'City': 'Louis Trichardt',
#   'Lat': -23.0439,
#   'Lng': 29.9032,
#   'Max Temp': 50.29,
#   'Humidity': 76,
#   'Cloudiness': 41,
#   'Wind Speed': 4.94,
#   'Country': 'ZA',
#   'Date': '2021-06-06 06:22:15',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Constitucion',
#   'Lat': -35.3333,
#   'Lng': -72.4167,
#   'Max Temp': 49.51,
#   'Humidity': 63,
#   'Cloudiness': 100,
#   'Wind Speed': 5.79,
#   'Country': 'CL',
#   'Date': '2021-06-06 06:22:16',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Planaltina',
#   'Lat': -15.4528,
#   'Lng': -47.6142,
#   'Max Temp': 66.49,
#   'Humidity': 81,
#   'Cloudiness': 72,
#   'Wind Speed': 4.29,
#   'Country': 'BR',
#   'Date': '2021-06-06 06:22:16',
#   'Current Description': 'broken clouds'},
#  {'City': 'Saldanha',
#   'Lat': -33.0117,
#   'Lng': 17.9442,
#   'Max Temp': 66.11,
#   'Humidity': 35,
#   'Cloudiness': 26,
#   'Wind Speed': 23,
#   'Country': 'ZA',
#   'Date': '2021-06-06 06:22:17',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Atuona',
#   'Lat': -9.8,
#   'Lng': -139.0333,
#   'Max Temp': 79.2,
#   'Humidity': 69,
#   'Cloudiness': 17,
#   'Wind Speed': 14.16,
#   'Country': 'PF',
#   'Date': '2021-06-06 06:22:17',
#   'Current Description': 'few clouds'},
#  {'City': 'Hervey Bay',
#   'Lat': -25.2986,
#   'Lng': 152.8535,
#   'Max Temp': 72.03,
#   'Humidity': 60,
#   'Cloudiness': 5,
#   'Wind Speed': 3,
#   'Country': 'AU',
#   'Date': '2021-06-06 06:22:17',
#   'Current Description': 'clear sky'},
#  {'City': 'Lata',
#   'Lat': 40.1629,
#   'Lng': -8.3327,
#   'Max Temp': 59.81,
#   'Humidity': 82,
#   'Cloudiness': 0,
#   'Wind Speed': 1.14,
#   'Country': 'PT',
#   'Date': '2021-06-06 06:22:19',
#   'Current Description': 'clear sky'},
#  {'City': 'Codrington',
#   'Lat': -38.2667,
#   'Lng': 141.9667,
#   'Max Temp': 60.51,
#   'Humidity': 73,
#   'Cloudiness': 100,
#   'Wind Speed': 14.85,
#   'Country': 'AU',
#   'Date': '2021-06-06 06:22:19',
#   'Current Description': 'overcast clouds'},
#  {'City': 'San Rafael',
#   'Lat': -34.6177,
#   'Lng': -68.3301,
#   'Max Temp': 47.86,
#   'Humidity': 56,
#   'Cloudiness': 73,
#   'Wind Speed': 3.13,
#   'Country': 'AR',
#   'Date': '2021-06-06 06:20:35',
#   'Current Description': 'broken clouds'},
#  {'City': 'Faanui',
#   'Lat': -16.4833,
#   'Lng': -151.75,
#   'Max Temp': 80.94,
#   'Humidity': 73,
#   'Cloudiness': 9,
#   'Wind Speed': 9.48,
#   'Country': 'PF',
#   'Date': '2021-06-06 06:22:20',
#   'Current Description': 'clear sky'},
#  {'City': 'Agas',
#   'Lat': 46.4833,
#   'Lng': 26.2167,
#   'Max Temp': 62.89,
#   'Humidity': 84,
#   'Cloudiness': 59,
#   'Wind Speed': 1.57,
#   'Country': 'RO',
#   'Date': '2021-06-06 06:22:20',
#   'Current Description': 'broken clouds'},
#  {'City': 'Kropotkin',
#   'Lat': 45.4375,
#   'Lng': 40.5756,
#   'Max Temp': 63.75,
#   'Humidity': 74,
#   'Cloudiness': 12,
#   'Wind Speed': 10.74,
#   'Country': 'RU',
#   'Date': '2021-06-06 06:22:21',
#   'Current Description': 'few clouds'},
#  {'City': 'Narsaq',
#   'Lat': 60.9167,
#   'Lng': -46.05,
#   'Max Temp': 44.82,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 1.79,
#   'Country': 'GL',
#   'Date': '2021-06-06 06:22:21',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Malinyi',
#   'Lat': -8.9333,
#   'Lng': 36.1333,
#   'Max Temp': 71.2,
#   'Humidity': 73,
#   'Cloudiness': 95,
#   'Wind Speed': 1.97,
#   'Country': 'TZ',
#   'Date': '2021-06-06 06:22:23',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Kpalime',
#   'Lat': 6.9,
#   'Lng': 0.6333,
#   'Max Temp': 72.3,
#   'Humidity': 94,
#   'Cloudiness': 93,
#   'Wind Speed': 0.83,
#   'Country': 'TG',
#   'Date': '2021-06-06 06:22:23',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Mahebourg',
#   'Lat': -20.4081,
#   'Lng': 57.7,
#   'Max Temp': 79.25,
#   'Humidity': 69,
#   'Cloudiness': 75,
#   'Wind Speed': 8.05,
#   'Country': 'MU',
#   'Date': '2021-06-06 06:22:23',
#   'Current Description': 'broken clouds'},
#  {'City': 'Shumikha',
#   'Lat': 55.2261,
#   'Lng': 63.2961,
#   'Max Temp': 67.98,
#   'Humidity': 38,
#   'Cloudiness': 0,
#   'Wind Speed': 9.78,
#   'Country': 'RU',
#   'Date': '2021-06-06 06:22:24',
#   'Current Description': 'clear sky'},
#  {'City': 'Avarua',
#   'Lat': -21.2078,
#   'Lng': -159.775,
#   'Max Temp': 73.45,
#   'Humidity': 68,
#   'Cloudiness': 40,
#   'Wind Speed': 3.44,
#   'Country': 'CK',
#   'Date': '2021-06-06 06:22:24',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Panguna',
#   'Lat': -6.3164,
#   'Lng': 155.4848,
#   'Max Temp': 74.73,
#   'Humidity': 91,
#   'Cloudiness': 42,
#   'Wind Speed': 2.21,
#   'Country': 'PG',
#   'Date': '2021-06-06 06:22:25',
#   'Current Description': 'light rain'},
#  {'City': 'Thompson',
#   'Lat': 55.7435,
#   'Lng': -97.8558,
#   'Max Temp': 53.76,
#   'Humidity': 94,
#   'Cloudiness': 75,
#   'Wind Speed': 4.61,
#   'Country': 'CA',
#   'Date': '2021-06-06 06:22:25',
#   'Current Description': 'broken clouds'},
#  {'City': 'Hithadhoo',
#   'Lat': -0.6,
#   'Lng': 73.0833,
#   'Max Temp': 83.37,
#   'Humidity': 72,
#   'Cloudiness': 76,
#   'Wind Speed': 13.04,
#   'Country': 'MV',
#   'Date': '2021-06-06 06:22:25',
#   'Current Description': 'broken clouds'},
#  {'City': 'Bilgoraj',
#   'Lat': 50.5411,
#   'Lng': 22.722,
#   'Max Temp': 62.37,
#   'Humidity': 74,
#   'Cloudiness': 6,
#   'Wind Speed': 4.83,
#   'Country': 'PL',
#   'Date': '2021-06-06 06:22:26',
#   'Current Description': 'clear sky'},
#  {'City': 'Esperance',
#   'Lat': -33.8667,
#   'Lng': 121.9,
#   'Max Temp': 67.84,
#   'Humidity': 59,
#   'Cloudiness': 35,
#   'Wind Speed': 18.5,
#   'Country': 'AU',
#   'Date': '2021-06-06 06:22:26',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Manitouwadge',
#   'Lat': 49.1215,
#   'Lng': -85.8403,
#   'Max Temp': 57.92,
#   'Humidity': 97,
#   'Cloudiness': 39,
#   'Wind Speed': 5.03,
#   'Country': 'CA',
#   'Date': '2021-06-06 06:22:27',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Qaanaaq',
#   'Lat': 77.484,
#   'Lng': -69.3632,
#   'Max Temp': 34.77,
#   'Humidity': 65,
#   'Cloudiness': 62,
#   'Wind Speed': 6.82,
#   'Country': 'GL',
#   'Date': '2021-06-06 06:22:27',
#   'Current Description': 'broken clouds'},
#  {'City': 'East London',
#   'Lat': -33.0153,
#   'Lng': 27.9116,
#   'Max Temp': 50.94,
#   'Humidity': 76,
#   'Cloudiness': 0,
#   'Wind Speed': 3.44,
#   'Country': 'ZA',
#   'Date': '2021-06-06 06:21:56',
#   'Current Description': 'clear sky'},
#  {'City': 'Mar Del Plata',
#   'Lat': -38.0023,
#   'Lng': -57.5575,
#   'Max Temp': 47.12,
#   'Humidity': 65,
#   'Cloudiness': 0,
#   'Wind Speed': 1.01,
#   'Country': 'AR',
#   'Date': '2021-06-06 06:21:12',
#   'Current Description': 'clear sky'},
#  {'City': 'Damara',
#   'Lat': 4.9608,
#   'Lng': 18.7035,
#   'Max Temp': 74.62,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 0.85,
#   'Country': 'CF',
#   'Date': '2021-06-06 06:22:28',
#   'Current Description': 'light rain'},
#  {'City': 'Manono',
#   'Lat': -7.3,
#   'Lng': 27.4167,
#   'Max Temp': 74.97,
#   'Humidity': 56,
#   'Cloudiness': 41,
#   'Wind Speed': 11.1,
#   'Country': 'CD',
#   'Date': '2021-06-06 06:22:28',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Clyde River',
#   'Lat': 70.4692,
#   'Lng': -68.5914,
#   'Max Temp': 32.23,
#   'Humidity': 100,
#   'Cloudiness': 90,
#   'Wind Speed': 12.66,
#   'Country': 'CA',
#   'Date': '2021-06-06 06:22:29',
#   'Current Description': 'light snow'},
#  {'City': 'San Jose',
#   'Lat': 37.3394,
#   'Lng': -121.895,
#   'Max Temp': 63.07,
#   'Humidity': 71,
#   'Cloudiness': 20,
#   'Wind Speed': 3.44,
#   'Country': 'US',
#   'Date': '2021-06-06 06:20:36',
#   'Current Description': 'few clouds'},
#  {'City': 'Atar',
#   'Lat': 20.5169,
#   'Lng': -13.0499,
#   'Max Temp': 84.96,
#   'Humidity': 17,
#   'Cloudiness': 98,
#   'Wind Speed': 11.68,
#   'Country': 'MR',
#   'Date': '2021-06-06 06:22:30',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Tasiilaq',
#   'Lat': 65.6145,
#   'Lng': -37.6368,
#   'Max Temp': 39.36,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 4.29,
#   'Country': 'GL',
#   'Date': '2021-06-06 06:22:30',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Bluff',
#   'Lat': -46.6,
#   'Lng': 168.3333,
#   'Max Temp': 49.8,
#   'Humidity': 76,
#   'Cloudiness': 81,
#   'Wind Speed': 4.83,
#   'Country': 'NZ',
#   'Date': '2021-06-06 06:22:30',
#   'Current Description': 'broken clouds'},
#  {'City': 'Mastic Beach',
#   'Lat': 40.7668,
#   'Lng': -72.8521,
#   'Max Temp': 77.67,
#   'Humidity': 85,
#   'Cloudiness': 1,
#   'Wind Speed': 1.01,
#   'Country': 'US',
#   'Date': '2021-06-06 06:22:31',
#   'Current Description': 'clear sky'},
#  {'City': 'Te Anau',
#   'Lat': -45.4167,
#   'Lng': 167.7167,
#   'Max Temp': 42.19,
#   'Humidity': 92,
#   'Cloudiness': 13,
#   'Wind Speed': 2.3,
#   'Country': 'NZ',
#   'Date': '2021-06-06 06:22:31',
#   'Current Description': 'few clouds'},
#  {'City': 'Tiksi',
#   'Lat': 71.6872,
#   'Lng': 128.8694,
#   'Max Temp': 46.17,
#   'Humidity': 48,
#   'Cloudiness': 94,
#   'Wind Speed': 6.53,
#   'Country': 'RU',
#   'Date': '2021-06-06 06:22:32',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Amli',
#   'Lat': 20.2833,
#   'Lng': 73.0167,
#   'Max Temp': 84.58,
#   'Humidity': 68,
#   'Cloudiness': 98,
#   'Wind Speed': 6.87,
#   'Country': 'IN',
#   'Date': '2021-06-06 06:22:32',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Dikson',
#   'Lat': 73.5069,
#   'Lng': 80.5464,
#   'Max Temp': 30.83,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 11.36,
#   'Country': 'RU',
#   'Date': '2021-06-06 06:22:32',
#   'Current Description': 'light snow'},
#  {'City': 'Oshakati',
#   'Lat': -17.7833,
#   'Lng': 15.6833,
#   'Max Temp': 53.62,
#   'Humidity': 42,
#   'Cloudiness': 0,
#   'Wind Speed': 8.12,
#   'Country': 'NA',
#   'Date': '2021-06-06 06:22:33',
#   'Current Description': 'clear sky'},
#  {'City': 'Geraldton',
#   'Lat': -28.7667,
#   'Lng': 114.6,
#   'Max Temp': 72.01,
#   'Humidity': 40,
#   'Cloudiness': 0,
#   'Wind Speed': 12.35,
#   'Country': 'AU',
#   'Date': '2021-06-06 06:22:33',
#   'Current Description': 'clear sky'},
#  {'City': 'Beringovskiy',
#   'Lat': 63.05,
#   'Lng': 179.3167,
#   'Max Temp': 39.2,
#   'Humidity': 87,
#   'Cloudiness': 65,
#   'Wind Speed': 3.96,
#   'Country': 'RU',
#   'Date': '2021-06-06 06:22:34',
#   'Current Description': 'broken clouds'},
#  {'City': 'Aswan',
#   'Lat': 24.0934,
#   'Lng': 32.907,
#   'Max Temp': 84.07,
#   'Humidity': 23,
#   'Cloudiness': 5,
#   'Wind Speed': 17.58,
#   'Country': 'EG',
#   'Date': '2021-06-06 06:22:34',
#   'Current Description': 'clear sky'},
#  {'City': 'Pacific Grove',
#   'Lat': 36.6177,
#   'Lng': -121.9166,
#   'Max Temp': 57.15,
#   'Humidity': 86,
#   'Cloudiness': 90,
#   'Wind Speed': 1.99,
#   'Country': 'US',
#   'Date': '2021-06-06 06:22:34',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Banda Aceh',
#   'Lat': 5.5577,
#   'Lng': 95.3222,
#   'Max Temp': 86.07,
#   'Humidity': 67,
#   'Cloudiness': 82,
#   'Wind Speed': 14,
#   'Country': 'ID',
#   'Date': '2021-06-06 06:22:35',
#   'Current Description': 'broken clouds'},
#  {'City': 'Pisco',
#   'Lat': -13.7,
#   'Lng': -76.2167,
#   'Max Temp': 64.45,
#   'Humidity': 82,
#   'Cloudiness': 90,
#   'Wind Speed': 3.44,
#   'Country': 'PE',
#   'Date': '2021-06-06 06:22:35',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Clinton',
#   'Lat': 42.587,
#   'Lng': -82.9199,
#   'Max Temp': 76.05,
#   'Humidity': 61,
#   'Cloudiness': 4,
#   'Wind Speed': 10.38,
#   'Country': 'US',
#   'Date': '2021-06-06 06:22:14',
#   'Current Description': 'clear sky'},
#  {'City': 'Rawson',
#   'Lat': -43.3002,
#   'Lng': -65.1023,
#   'Max Temp': 43,
#   'Humidity': 60,
#   'Cloudiness': 1,
#   'Wind Speed': 9.84,
#   'Country': 'AR',
#   'Date': '2021-06-06 06:22:36',
#   'Current Description': 'clear sky'},
#  {'City': 'Stykkisholmur',
#   'Lat': 65.0757,
#   'Lng': -22.7297,
#   'Max Temp': 46.27,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 6.17,
#   'Country': 'IS',
#   'Date': '2021-06-06 06:22:36',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Mehamn',
#   'Lat': 71.0357,
#   'Lng': 27.8492,
#   'Max Temp': 42.55,
#   'Humidity': 77,
#   'Cloudiness': 10,
#   'Wind Speed': 19.91,
#   'Country': 'NO',
#   'Date': '2021-06-06 06:22:37',
#   'Current Description': 'clear sky'},
#  {'City': 'Bajil',
#   'Lat': 15.0584,
#   'Lng': 43.2851,
#   'Max Temp': 92.77,
#   'Humidity': 47,
#   'Cloudiness': 0,
#   'Wind Speed': 5.21,
#   'Country': 'YE',
#   'Date': '2021-06-06 06:22:37',
#   'Current Description': 'clear sky'},
#  {'City': 'Kaitangata',
#   'Lat': -46.2817,
#   'Lng': 169.8464,
#   'Max Temp': 50.94,
#   'Humidity': 70,
#   'Cloudiness': 60,
#   'Wind Speed': 0.89,
#   'Country': 'NZ',
#   'Date': '2021-06-06 06:22:37',
#   'Current Description': 'broken clouds'},
#  {'City': 'Bredasdorp',
#   'Lat': -34.5322,
#   'Lng': 20.0403,
#   'Max Temp': 42.12,
#   'Humidity': 75,
#   'Cloudiness': 4,
#   'Wind Speed': 6.24,
#   'Country': 'ZA',
#   'Date': '2021-06-06 06:22:38',
#   'Current Description': 'clear sky'},
#  {'City': 'Sola',
#   'Lat': -13.8833,
#   'Lng': 167.55,
#   'Max Temp': 81.27,
#   'Humidity': 78,
#   'Cloudiness': 40,
#   'Wind Speed': 0,
#   'Country': 'VU',
#   'Date': '2021-06-06 06:22:38',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Caravelas',
#   'Lat': -17.7125,
#   'Lng': -39.2481,
#   'Max Temp': 71.33,
#   'Humidity': 90,
#   'Cloudiness': 21,
#   'Wind Speed': 5.66,
#   'Country': 'BR',
#   'Date': '2021-06-06 06:22:39',
#   'Current Description': 'few clouds'},
#  {'City': 'Beira',
#   'Lat': -19.8436,
#   'Lng': 34.8389,
#   'Max Temp': 62.6,
#   'Humidity': 88,
#   'Cloudiness': 75,
#   'Wind Speed': 11.5,
#   'Country': 'MZ',
#   'Date': '2021-06-06 06:22:39',
#   'Current Description': 'broken clouds'},
#  {'City': 'Uddevalla',
#   'Lat': 58.3478,
#   'Lng': 11.9424,
#   'Max Temp': 70.18,
#   'Humidity': 60,
#   'Cloudiness': 94,
#   'Wind Speed': 4.09,
#   'Country': 'SE',
#   'Date': '2021-06-06 06:22:40',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Albany',
#   'Lat': 42.6001,
#   'Lng': -73.9662,
#   'Max Temp': 70.21,
#   'Humidity': 77,
#   'Cloudiness': 46,
#   'Wind Speed': 3.91,
#   'Country': 'US',
#   'Date': '2021-06-06 06:18:58',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Nanortalik',
#   'Lat': 60.1432,
#   'Lng': -45.2371,
#   'Max Temp': 39.02,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 5.64,
#   'Country': 'GL',
#   'Date': '2021-06-06 06:22:40',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Port Elizabeth',
#   'Lat': -33.918,
#   'Lng': 25.5701,
#   'Max Temp': 55.69,
#   'Humidity': 54,
#   'Cloudiness': 0,
#   'Wind Speed': 8.05,
#   'Country': 'ZA',
#   'Date': '2021-06-06 06:22:41',
#   'Current Description': 'clear sky'},
#  {'City': 'Hamilton',
#   'Lat': 39.1834,
#   'Lng': -84.5333,
#   'Max Temp': 70.56,
#   'Humidity': 86,
#   'Cloudiness': 1,
#   'Wind Speed': 2.98,
#   'Country': 'US',
#   'Date': '2021-06-06 06:17:53',
#   'Current Description': 'clear sky'},
#  {'City': 'Vozdvizhenka',
#   'Lat': 43.9,
#   'Lng': 131.95,
#   'Max Temp': 73.15,
#   'Humidity': 55,
#   'Cloudiness': 46,
#   'Wind Speed': 4.79,
#   'Country': 'RU',
#   'Date': '2021-06-06 06:22:41',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Kununurra',
#   'Lat': -15.7667,
#   'Lng': 128.7333,
#   'Max Temp': 84.18,
#   'Humidity': 23,
#   'Cloudiness': 64,
#   'Wind Speed': 8.05,
#   'Country': 'AU',
#   'Date': '2021-06-06 06:22:42',
#   'Current Description': 'broken clouds'},
#  {'City': 'Lorengau',
#   'Lat': -2.0226,
#   'Lng': 147.2712,
#   'Max Temp': 81.9,
#   'Humidity': 76,
#   'Cloudiness': 98,
#   'Wind Speed': 6.93,
#   'Country': 'PG',
#   'Date': '2021-06-06 06:22:44',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Kenai',
#   'Lat': 60.5544,
#   'Lng': -151.2583,
#   'Max Temp': 60.89,
#   'Humidity': 71,
#   'Cloudiness': 90,
#   'Wind Speed': 10.36,
#   'Country': 'US',
#   'Date': '2021-06-06 06:22:44',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Kloulklubed',
#   'Lat': 7.0419,
#   'Lng': 134.2556,
#   'Max Temp': 86.5,
#   'Humidity': 78,
#   'Cloudiness': 84,
#   'Wind Speed': 7.2,
#   'Country': 'PW',
#   'Date': '2021-06-06 06:22:45',
#   'Current Description': 'broken clouds'},
#  {'City': 'Vila Velha',
#   'Lat': -20.3297,
#   'Lng': -40.2925,
#   'Max Temp': 69.75,
#   'Humidity': 96,
#   'Cloudiness': 90,
#   'Wind Speed': 3,
#   'Country': 'BR',
#   'Date': '2021-06-06 06:19:39',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Isla Mujeres',
#   'Lat': 21.2311,
#   'Lng': -86.731,
#   'Max Temp': 82.45,
#   'Humidity': 81,
#   'Cloudiness': 99,
#   'Wind Speed': 11.86,
#   'Country': 'MX',
#   'Date': '2021-06-06 06:22:45',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Dindori',
#   'Lat': 22.95,
#   'Lng': 81.0833,
#   'Max Temp': 92.46,
#   'Humidity': 36,
#   'Cloudiness': 35,
#   'Wind Speed': 14.5,
#   'Country': 'IN',
#   'Date': '2021-06-06 06:22:46',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Ceres',
#   'Lat': 37.5949,
#   'Lng': -120.9577,
#   'Max Temp': 77.58,
#   'Humidity': 49,
#   'Cloudiness': 1,
#   'Wind Speed': 5.75,
#   'Country': 'US',
#   'Date': '2021-06-06 06:22:46',
#   'Current Description': 'clear sky'},
#  {'City': 'Leningradskiy',
#   'Lat': 69.3833,
#   'Lng': 178.4167,
#   'Max Temp': 37.58,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 11.68,
#   'Country': 'RU',
#   'Date': '2021-06-06 06:22:47',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Port Macquarie',
#   'Lat': -31.4333,
#   'Lng': 152.9167,
#   'Max Temp': 62.56,
#   'Humidity': 54,
#   'Cloudiness': 0,
#   'Wind Speed': 6.85,
#   'Country': 'AU',
#   'Date': '2021-06-06 06:19:58',
#   'Current Description': 'clear sky'},
#  {'City': 'Karaton',
#   'Lat': -6.3424,
#   'Lng': 106.1045,
#   'Max Temp': 87.96,
#   'Humidity': 62,
#   'Cloudiness': 40,
#   'Wind Speed': 3.98,
#   'Country': 'ID',
#   'Date': '2021-06-06 06:22:48',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Wilmington Island',
#   'Lat': 32.0036,
#   'Lng': -80.9737,
#   'Max Temp': 79.99,
#   'Humidity': 65,
#   'Cloudiness': 90,
#   'Wind Speed': 1.99,
#   'Country': 'US',
#   'Date': '2021-06-06 06:19:33',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Palmer',
#   'Lat': 42.1584,
#   'Lng': -72.3287,
#   'Max Temp': 74.37,
#   'Humidity': 82,
#   'Cloudiness': 1,
#   'Wind Speed': 3.47,
#   'Country': 'US',
#   'Date': '2021-06-06 06:22:48',
#   'Current Description': 'clear sky'},
#  {'City': 'Cockburn Town',
#   'Lat': 21.4612,
#   'Lng': -71.1419,
#   'Max Temp': 79.93,
#   'Humidity': 79,
#   'Cloudiness': 0,
#   'Wind Speed': 23.13,
#   'Country': 'TC',
#   'Date': '2021-06-06 06:18:32',
#   'Current Description': 'clear sky'},
#  {'City': 'Abonnema',
#   'Lat': 4.7084,
#   'Lng': 6.7931,
#   'Max Temp': 74.48,
#   'Humidity': 95,
#   'Cloudiness': 91,
#   'Wind Speed': 1.72,
#   'Country': 'NG',
#   'Date': '2021-06-06 06:22:49',
#   'Current Description': 'moderate rain'},
#  {'City': 'Hobart',
#   'Lat': -42.8794,
#   'Lng': 147.3294,
#   'Max Temp': 52.27,
#   'Humidity': 75,
#   'Cloudiness': 75,
#   'Wind Speed': 1.01,
#   'Country': 'AU',
#   'Date': '2021-06-06 06:22:49',
#   'Current Description': 'light rain'},
#  {'City': 'Sao Joao Da Barra',
#   'Lat': -21.6403,
#   'Lng': -41.0511,
#   'Max Temp': 71.13,
#   'Humidity': 89,
#   'Cloudiness': 0,
#   'Wind Speed': 9.26,
#   'Country': 'BR',
#   'Date': '2021-06-06 06:22:50',
#   'Current Description': 'clear sky'},
#  {'City': 'Ponta Do Sol',
#   'Lat': 32.6667,
#   'Lng': -17.1,
#   'Max Temp': 66.83,
#   'Humidity': 71,
#   'Cloudiness': 54,
#   'Wind Speed': 5.97,
#   'Country': 'PT',
#   'Date': '2021-06-06 06:22:51',
#   'Current Description': 'broken clouds'},
#  {'City': 'Broome',
#   'Lat': 42.2506,
#   'Lng': -75.833,
#   'Max Temp': 69.66,
#   'Humidity': 76,
#   'Cloudiness': 74,
#   'Wind Speed': 4.21,
#   'Country': 'US',
#   'Date': '2021-06-06 06:22:51',
#   'Current Description': 'broken clouds'},
#  {'City': 'Tuatapere',
#   'Lat': -46.1333,
#   'Lng': 167.6833,
#   'Max Temp': 49.82,
#   'Humidity': 88,
#   'Cloudiness': 48,
#   'Wind Speed': 3.4,
#   'Country': 'NZ',
#   'Date': '2021-06-06 06:22:52',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Waipawa',
#   'Lat': -41.4122,
#   'Lng': 175.5153,
#   'Max Temp': 59,
#   'Humidity': 77,
#   'Cloudiness': 75,
#   'Wind Speed': 2.3,
#   'Country': 'NZ',
#   'Date': '2021-06-06 06:22:52',
#   'Current Description': 'broken clouds'},
#  {'City': 'Naryan-Mar',
#   'Lat': 67.6713,
#   'Lng': 53.087,
#   'Max Temp': 43.68,
#   'Humidity': 47,
#   'Cloudiness': 64,
#   'Wind Speed': 15.52,
#   'Country': 'RU',
#   'Date': '2021-06-06 06:22:53',
#   'Current Description': 'broken clouds'},
#  {'City': 'Gat',
#   'Lat': 31.61,
#   'Lng': 34.7642,
#   'Max Temp': 77.4,
#   'Humidity': 53,
#   'Cloudiness': 0,
#   'Wind Speed': 4.65,
#   'Country': 'IL',
#   'Date': '2021-06-06 06:22:54',
#   'Current Description': 'clear sky'},
#  {'City': 'Hilo',
#   'Lat': 19.7297,
#   'Lng': -155.09,
#   'Max Temp': 75.2,
#   'Humidity': 69,
#   'Cloudiness': 1,
#   'Wind Speed': 4.61,
#   'Country': 'US',
#   'Date': '2021-06-06 06:22:54',
#   'Current Description': 'clear sky'},
#  {'City': 'Dongtai',
#   'Lat': 32.8523,
#   'Lng': 120.3095,
#   'Max Temp': 96.46,
#   'Humidity': 21,
#   'Cloudiness': 3,
#   'Wind Speed': 9.8,
#   'Country': 'CN',
#   'Date': '2021-06-06 06:22:55',
#   'Current Description': 'clear sky'},
#  {'City': 'Khor',
#   'Lat': 47.8861,
#   'Lng': 134.9464,
#   'Max Temp': 63.05,
#   'Humidity': 59,
#   'Cloudiness': 94,
#   'Wind Speed': 7.72,
#   'Country': 'RU',
#   'Date': '2021-06-06 06:22:56',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Nikolskoye',
#   'Lat': 59.7035,
#   'Lng': 30.7861,
#   'Max Temp': 71.6,
#   'Humidity': 53,
#   'Cloudiness': 0,
#   'Wind Speed': 6.71,
#   'Country': 'RU',
#   'Date': '2021-06-06 06:22:57',
#   'Current Description': 'clear sky'},
#  {'City': 'Pingliang',
#   'Lat': 35.5392,
#   'Lng': 106.6861,
#   'Max Temp': 86.36,
#   'Humidity': 22,
#   'Cloudiness': 100,
#   'Wind Speed': 1.5,
#   'Country': 'CN',
#   'Date': '2021-06-06 06:22:57',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Shelburne',
#   'Lat': 44.0787,
#   'Lng': -80.2041,
#   'Max Temp': 73.89,
#   'Humidity': 55,
#   'Cloudiness': 67,
#   'Wind Speed': 15.79,
#   'Country': 'CA',
#   'Date': '2021-06-06 06:22:58',
#   'Current Description': 'broken clouds'},
#  {'City': 'Faya',
#   'Lat': 18.3851,
#   'Lng': 42.4509,
#   'Max Temp': 80.71,
#   'Humidity': 25,
#   'Cloudiness': 0,
#   'Wind Speed': 4.29,
#   'Country': 'SA',
#   'Date': '2021-06-06 06:22:58',
#   'Current Description': 'clear sky'},
#  {'City': 'Sabzevar',
#   'Lat': 36.2126,
#   'Lng': 57.6819,
#   'Max Temp': 93.2,
#   'Humidity': 26,
#   'Cloudiness': 0,
#   'Wind Speed': 9.22,
#   'Country': 'IR',
#   'Date': '2021-06-06 06:22:59',
#   'Current Description': 'clear sky'},
#  {'City': 'Puerto Ayora',
#   'Lat': -0.7393,
#   'Lng': -90.3518,
#   'Max Temp': 72.55,
#   'Humidity': 93,
#   'Cloudiness': 19,
#   'Wind Speed': 1.99,
#   'Country': 'EC',
#   'Date': '2021-06-06 06:23:00',
#   'Current Description': 'few clouds'},
#  {'City': 'Byumba',
#   'Lat': -1.5763,
#   'Lng': 30.0675,
#   'Max Temp': 59.2,
#   'Humidity': 85,
#   'Cloudiness': 98,
#   'Wind Speed': 4.07,
#   'Country': 'RW',
#   'Date': '2021-06-06 06:23:00',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Ulaangom',
#   'Lat': 49.9811,
#   'Lng': 92.0667,
#   'Max Temp': 58.64,
#   'Humidity': 23,
#   'Cloudiness': 81,
#   'Wind Speed': 18.52,
#   'Country': 'MN',
#   'Date': '2021-06-06 06:23:01',
#   'Current Description': 'broken clouds'},
#  {'City': 'Kodiak',
#   'Lat': 57.79,
#   'Lng': -152.4072,
#   'Max Temp': 56.71,
#   'Humidity': 47,
#   'Cloudiness': 1,
#   'Wind Speed': 17.27,
#   'Country': 'US',
#   'Date': '2021-06-06 06:22:26',
#   'Current Description': 'clear sky'},
#  {'City': 'Khatanga',
#   'Lat': 71.9667,
#   'Lng': 102.5,
#   'Max Temp': 38.68,
#   'Humidity': 66,
#   'Cloudiness': 100,
#   'Wind Speed': 10.76,
#   'Country': 'RU',
#   'Date': '2021-06-06 06:23:01',
#   'Current Description': 'light rain'},
#  {'City': 'Yar-Sale',
#   'Lat': 66.8333,
#   'Lng': 70.8333,
#   'Max Temp': 44.55,
#   'Humidity': 48,
#   'Cloudiness': 98,
#   'Wind Speed': 17.78,
#   'Country': 'RU',
#   'Date': '2021-06-06 06:23:02',
#   'Current Description': 'light rain'},
#  {'City': 'Babushkin',
#   'Lat': 51.7122,
#   'Lng': 105.8647,
#   'Max Temp': 42.06,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 24.9,
#   'Country': 'RU',
#   'Date': '2021-06-06 06:23:02',
#   'Current Description': 'light rain'},
#  {'City': 'Portland',
#   'Lat': 45.5234,
#   'Lng': -122.6762,
#   'Max Temp': 53.56,
#   'Humidity': 77,
#   'Cloudiness': 20,
#   'Wind Speed': 5.75,
#   'Country': 'US',
#   'Date': '2021-06-06 06:21:47',
#   'Current Description': 'few clouds'},
#  {'City': 'Pangnirtung',
#   'Lat': 66.1451,
#   'Lng': -65.7125,
#   'Max Temp': 23.81,
#   'Humidity': 92,
#   'Cloudiness': 64,
#   'Wind Speed': 5.64,
#   'Country': 'CA',
#   'Date': '2021-06-06 06:23:03',
#   'Current Description': 'broken clouds'},
#  {'City': 'Kosh-Agach',
#   'Lat': 50,
#   'Lng': 88.6667,
#   'Max Temp': 50.38,
#   'Humidity': 26,
#   'Cloudiness': 34,
#   'Wind Speed': 7.92,
#   'Country': 'RU',
#   'Date': '2021-06-06 06:23:04',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Leshukonskoye',
#   'Lat': 64.8989,
#   'Lng': 45.7622,
#   'Max Temp': 56.43,
#   'Humidity': 38,
#   'Cloudiness': 86,
#   'Wind Speed': 7.25,
#   'Country': 'RU',
#   'Date': '2021-06-06 06:23:04',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Lagos',
#   'Lat': 6.5833,
#   'Lng': 3.75,
#   'Max Temp': 77.32,
#   'Humidity': 94,
#   'Cloudiness': 73,
#   'Wind Speed': 1.7,
#   'Country': 'NG',
#   'Date': '2021-06-06 06:21:40',
#   'Current Description': 'broken clouds'},
#  {'City': 'Marion',
#   'Lat': 39.7684,
#   'Lng': -86.1555,
#   'Max Temp': 70,
#   'Humidity': 87,
#   'Cloudiness': 20,
#   'Wind Speed': 4.45,
#   'Country': 'US',
#   'Date': '2021-06-06 06:20:29',
#   'Current Description': 'few clouds'},
#  {'City': 'Chernyshevskiy',
#   'Lat': 63.0128,
#   'Lng': 112.4714,
#   'Max Temp': 59.95,
#   'Humidity': 23,
#   'Cloudiness': 45,
#   'Wind Speed': 6.98,
#   'Country': 'RU',
#   'Date': '2021-06-06 06:23:06',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Odda',
#   'Lat': 60.0691,
#   'Lng': 6.5457,
#   'Max Temp': 57.99,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 1.74,
#   'Country': 'NO',
#   'Date': '2021-06-06 06:23:07',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Maningrida',
#   'Lat': -12.0667,
#   'Lng': 134.2667,
#   'Max Temp': 83.03,
#   'Humidity': 54,
#   'Cloudiness': 33,
#   'Wind Speed': 10.96,
#   'Country': 'AU',
#   'Date': '2021-06-06 06:23:07',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Iqaluit',
#   'Lat': 63.7506,
#   'Lng': -68.5145,
#   'Max Temp': 31.73,
#   'Humidity': 93,
#   'Cloudiness': 90,
#   'Wind Speed': 1.99,
#   'Country': 'CA',
#   'Date': '2021-06-06 06:23:08',
#   'Current Description': 'light snow'},
#  {'City': 'Bubaque',
#   'Lat': 11.2833,
#   'Lng': -15.8333,
#   'Max Temp': 79.47,
#   'Humidity': 84,
#   'Cloudiness': 97,
#   'Wind Speed': 10.42,
#   'Country': 'GW',
#   'Date': '2021-06-06 06:23:08',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Moroni',
#   'Lat': -11.7022,
#   'Lng': 43.2551,
#   'Max Temp': 78.15,
#   'Humidity': 76,
#   'Cloudiness': 72,
#   'Wind Speed': 18.79,
#   'Country': 'KM',
#   'Date': '2021-06-06 06:23:09',
#   'Current Description': 'light rain'},
#  {'City': 'Bagado',
#   'Lat': 5.4116,
#   'Lng': -76.4152,
#   'Max Temp': 75.09,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 0.98,
#   'Country': 'CO',
#   'Date': '2021-06-06 06:23:09',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Tucuma',
#   'Lat': -0.1833,
#   'Lng': -50.05,
#   'Max Temp': 75.13,
#   'Humidity': 93,
#   'Cloudiness': 48,
#   'Wind Speed': 3.94,
#   'Country': 'BR',
#   'Date': '2021-06-06 06:19:14',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Rock Springs',
#   'Lat': 41.5875,
#   'Lng': -109.2029,
#   'Max Temp': 67.44,
#   'Humidity': 32,
#   'Cloudiness': 1,
#   'Wind Speed': 6.82,
#   'Country': 'US',
#   'Date': '2021-06-06 06:23:10',
#   'Current Description': 'clear sky'},
#  {'City': 'Koulikoro',
#   'Lat': 14,
#   'Lng': -7.75,
#   'Max Temp': 86.29,
#   'Humidity': 36,
#   'Cloudiness': 32,
#   'Wind Speed': 14.72,
#   'Country': 'ML',
#   'Date': '2021-06-06 06:23:11',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Mercedes',
#   'Lat': -34.6515,
#   'Lng': -59.4307,
#   'Max Temp': 45.84,
#   'Humidity': 63,
#   'Cloudiness': 34,
#   'Wind Speed': 5.97,
#   'Country': 'AR',
#   'Date': '2021-06-06 06:23:11',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Cidreira',
#   'Lat': -30.1811,
#   'Lng': -50.2056,
#   'Max Temp': 62.87,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 5.26,
#   'Country': 'BR',
#   'Date': '2021-06-06 06:23:12',
#   'Current Description': 'heavy intensity rain'},
#  {'City': 'Coihaique',
#   'Lat': -45.5752,
#   'Lng': -72.0662,
#   'Max Temp': 39.15,
#   'Humidity': 75,
#   'Cloudiness': 40,
#   'Wind Speed': 5.75,
#   'Country': 'CL',
#   'Date': '2021-06-06 06:23:12',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Alindao',
#   'Lat': 5.0267,
#   'Lng': 21.2088,
#   'Max Temp': 69.58,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 2.93,
#   'Country': 'CF',
#   'Date': '2021-06-06 06:23:13',
#   'Current Description': 'light rain'},
#  {'City': 'Gamboma',
#   'Lat': -1.8764,
#   'Lng': 15.8644,
#   'Max Temp': 73.92,
#   'Humidity': 85,
#   'Cloudiness': 97,
#   'Wind Speed': 3.62,
#   'Country': 'CG',
#   'Date': '2021-06-06 06:23:13',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Puerto Escondido',
#   'Lat': 15.85,
#   'Lng': -97.0667,
#   'Max Temp': 82.4,
#   'Humidity': 80,
#   'Cloudiness': 100,
#   'Wind Speed': 4.94,
#   'Country': 'MX',
#   'Date': '2021-06-06 06:23:14',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Chishtian Mandi',
#   'Lat': 29.8,
#   'Lng': 72.8667,
#   'Max Temp': 101.84,
#   'Humidity': 26,
#   'Cloudiness': 0,
#   'Wind Speed': 5.82,
#   'Country': 'PK',
#   'Date': '2021-06-06 06:23:14',
#   'Current Description': 'clear sky'},
#  {'City': 'Payo',
#   'Lat': -3.7508,
#   'Lng': 103.6372,
#   'Max Temp': 93.11,
#   'Humidity': 47,
#   'Cloudiness': 19,
#   'Wind Speed': 2.26,
#   'Country': 'ID',
#   'Date': '2021-06-06 06:23:14',
#   'Current Description': 'few clouds'},
#  {'City': 'Barrow',
#   'Lat': 71.2906,
#   'Lng': -156.7887,
#   'Max Temp': 33.82,
#   'Humidity': 86,
#   'Cloudiness': 90,
#   'Wind Speed': 12.66,
#   'Country': 'US',
#   'Date': '2021-06-06 06:23:15',
#   'Current Description': 'fog'},
#  {'City': 'Jambi',
#   'Lat': -1.6,
#   'Lng': 103.6167,
#   'Max Temp': 92.03,
#   'Humidity': 48,
#   'Cloudiness': 64,
#   'Wind Speed': 3.83,
#   'Country': 'ID',
#   'Date': '2021-06-06 06:23:15',
#   'Current Description': 'broken clouds'},
#  {'City': 'Cabo San Lucas',
#   'Lat': 22.8909,
#   'Lng': -109.9124,
#   'Max Temp': 84.4,
#   'Humidity': 57,
#   'Cloudiness': 2,
#   'Wind Speed': 11.25,
#   'Country': 'MX',
#   'Date': '2021-06-06 06:19:51',
#   'Current Description': 'clear sky'},
#  {'City': 'Asau',
#   'Lat': 46.4333,
#   'Lng': 26.4,
#   'Max Temp': 64.76,
#   'Humidity': 74,
#   'Cloudiness': 56,
#   'Wind Speed': 1.12,
#   'Country': 'RO',
#   'Date': '2021-06-06 06:23:16',
#   'Current Description': 'broken clouds'},
#  {'City': 'Yeppoon',
#   'Lat': -23.1333,
#   'Lng': 150.7333,
#   'Max Temp': 74.98,
#   'Humidity': 61,
#   'Cloudiness': 8,
#   'Wind Speed': 8.05,
#   'Country': 'AU',
#   'Date': '2021-06-06 06:23:17',
#   'Current Description': 'clear sky'},
#  {'City': 'Talnakh',
#   'Lat': 69.4865,
#   'Lng': 88.3972,
#   'Max Temp': 33.04,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 5.61,
#   'Country': 'RU',
#   'Date': '2021-06-06 06:23:17',
#   'Current Description': 'light snow'},
#  {'City': 'Cape Town',
#   'Lat': -33.9258,
#   'Lng': 18.4232,
#   'Max Temp': 61.21,
#   'Humidity': 29,
#   'Cloudiness': 0,
#   'Wind Speed': 8.43,
#   'Country': 'ZA',
#   'Date': '2021-06-06 06:20:28',
#   'Current Description': 'clear sky'},
#  {'City': 'Yarmouth',
#   'Lat': 41.7057,
#   'Lng': -70.2286,
#   'Max Temp': 72,
#   'Humidity': 78,
#   'Cloudiness': 1,
#   'Wind Speed': 9.22,
#   'Country': 'US',
#   'Date': '2021-06-06 06:23:18',
#   'Current Description': 'clear sky'},
#  {'City': 'Zhanaozen',
#   'Lat': 43.3,
#   'Lng': 52.8,
#   'Max Temp': 78.28,
#   'Humidity': 42,
#   'Cloudiness': 12,
#   'Wind Speed': 17.29,
#   'Country': 'KZ',
#   'Date': '2021-06-06 06:23:19',
#   'Current Description': 'few clouds'},
#  {'City': 'Nagua',
#   'Lat': 19.3832,
#   'Lng': -69.8474,
#   'Max Temp': 74.44,
#   'Humidity': 88,
#   'Cloudiness': 14,
#   'Wind Speed': 7.18,
#   'Country': 'DO',
#   'Date': '2021-06-06 06:23:09',
#   'Current Description': 'few clouds'},
#  {'City': 'Tiarei',
#   'Lat': -17.5333,
#   'Lng': -149.3333,
#   'Max Temp': 78.82,
#   'Humidity': 80,
#   'Cloudiness': 14,
#   'Wind Speed': 12.15,
#   'Country': 'PF',
#   'Date': '2021-06-06 06:23:19',
#   'Current Description': 'few clouds'},
#  {'City': 'Lebu',
#   'Lat': -37.6167,
#   'Lng': -73.65,
#   'Max Temp': 47.84,
#   'Humidity': 78,
#   'Cloudiness': 95,
#   'Wind Speed': 10.16,
#   'Country': 'CL',
#   'Date': '2021-06-06 06:23:20',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Dwarka',
#   'Lat': 22.2394,
#   'Lng': 68.9678,
#   'Max Temp': 88.65,
#   'Humidity': 59,
#   'Cloudiness': 26,
#   'Wind Speed': 12.64,
#   'Country': 'IN',
#   'Date': '2021-06-06 06:23:21',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Tarnow',
#   'Lat': 50.0138,
#   'Lng': 20.987,
#   'Max Temp': 64.09,
#   'Humidity': 83,
#   'Cloudiness': 0,
#   'Wind Speed': 2.39,
#   'Country': 'PL',
#   'Date': '2021-06-06 06:23:21',
#   'Current Description': 'clear sky'},
#  {'City': 'Boyolangu',
#   'Lat': -8.1181,
#   'Lng': 111.8935,
#   'Max Temp': 85.23,
#   'Humidity': 67,
#   'Cloudiness': 22,
#   'Wind Speed': 7.27,
#   'Country': 'ID',
#   'Date': '2021-06-06 06:23:22',
#   'Current Description': 'few clouds'},
#  {'City': 'Saint Anthony',
#   'Lat': 45.0205,
#   'Lng': -93.218,
#   'Max Temp': 86.02,
#   'Humidity': 46,
#   'Cloudiness': 1,
#   'Wind Speed': 1.99,
#   'Country': 'US',
#   'Date': '2021-06-06 06:23:22',
#   'Current Description': 'clear sky'},
#  {'City': 'Puerto Del Rosario',
#   'Lat': 28.5004,
#   'Lng': -13.8627,
#   'Max Temp': 64.4,
#   'Humidity': 72,
#   'Cloudiness': 20,
#   'Wind Speed': 11.5,
#   'Country': 'ES',
#   'Date': '2021-06-06 06:23:23',
#   'Current Description': 'few clouds'},
#  {'City': 'Hof',
#   'Lat': 50.3167,
#   'Lng': 11.9167,
#   'Max Temp': 62.01,
#   'Humidity': 10,
#   'Cloudiness': 100,
#   'Wind Speed': 4,
#   'Country': 'DE',
#   'Date': '2021-06-06 06:23:24',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Bud',
#   'Lat': 39.447,
#   'Lng': -86.1758,
#   'Max Temp': 69.15,
#   'Humidity': 90,
#   'Cloudiness': 32,
#   'Wind Speed': 5.12,
#   'Country': 'US',
#   'Date': '2021-06-06 06:23:24',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Biltine',
#   'Lat': 14.5333,
#   'Lng': 20.9167,
#   'Max Temp': 83.03,
#   'Humidity': 51,
# ...
#   'Cloudiness': 0,
#   'Wind Speed': 24.16,
#   'Country': 'CV',
#   'Date': '2021-06-06 06:26:52',
#   'Current Description': 'clear sky'},
#  {'City': 'Staraya Russa',
#   'Lat': 57.9944,
#   'Lng': 31.3608,
#   'Max Temp': 67.71,
#   'Humidity': 60,
#   'Cloudiness': 0,
#   'Wind Speed': 1.99,
#   'Country': 'RU',
#   'Date': '2021-06-06 06:26:52',
#   'Current Description': 'clear sky'},
#  {'City': 'Teya',
#   'Lat': 60.3778,
#   'Lng': 92.6267,
#   'Max Temp': 52,
#   'Humidity': 38,
#   'Cloudiness': 91,
#   'Wind Speed': 11.81,
#   'Country': 'RU',
#   'Date': '2021-06-06 06:26:53',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Pitea',
#   'Lat': 65.3172,
#   'Lng': 21.4794,
#   'Max Temp': 62.69,
#   'Humidity': 67,
#   'Cloudiness': 72,
#   'Wind Speed': 6.73,
#   'Country': 'SE',
#   'Date': '2021-06-06 06:26:53',
#   'Current Description': 'broken clouds'},
#  {'City': 'Port Blair',
#   'Lat': 11.6667,
#   'Lng': 92.75,
#   'Max Temp': 86.61,
#   'Humidity': 69,
#   'Cloudiness': 100,
#   'Wind Speed': 12.53,
#   'Country': 'IN',
#   'Date': '2021-06-06 06:26:54',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Treinta Y Tres',
#   'Lat': -33.2333,
#   'Lng': -54.3833,
#   'Max Temp': 46.15,
#   'Humidity': 87,
#   'Cloudiness': 85,
#   'Wind Speed': 4.79,
#   'Country': 'UY',
#   'Date': '2021-06-06 06:26:54',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Bacolod',
#   'Lat': 10.6667,
#   'Lng': 122.95,
#   'Max Temp': 81.54,
#   'Humidity': 82,
#   'Cloudiness': 85,
#   'Wind Speed': 13.53,
#   'Country': 'PH',
#   'Date': '2021-06-06 06:26:55',
#   'Current Description': 'light rain'},
#  {'City': 'Kuytun',
#   'Lat': 54.3419,
#   'Lng': 101.5036,
#   'Max Temp': 54.48,
#   'Humidity': 52,
#   'Cloudiness': 100,
#   'Wind Speed': 15.55,
#   'Country': 'RU',
#   'Date': '2021-06-06 06:26:55',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Walvis Bay',
#   'Lat': -22.9575,
#   'Lng': 14.5053,
#   'Max Temp': 74.35,
#   'Humidity': 21,
#   'Cloudiness': 0,
#   'Wind Speed': 29.48,
#   'Country': 'NA',
#   'Date': '2021-06-06 06:26:56',
#   'Current Description': 'clear sky'},
#  {'City': 'Saint-Georges',
#   'Lat': 12.0564,
#   'Lng': -61.7485,
#   'Max Temp': 80.28,
#   'Humidity': 78,
#   'Cloudiness': 40,
#   'Wind Speed': 19.57,
#   'Country': 'GD',
#   'Date': '2021-06-06 06:26:56',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Akyab',
#   'Lat': 20.15,
#   'Lng': 92.9,
#   'Max Temp': 83.34,
#   'Humidity': 76,
#   'Cloudiness': 98,
#   'Wind Speed': 9.24,
#   'Country': 'MM',
#   'Date': '2021-06-06 06:26:56',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Hay River',
#   'Lat': 60.8156,
#   'Lng': -115.7999,
#   'Max Temp': 44.56,
#   'Humidity': 87,
#   'Cloudiness': 20,
#   'Wind Speed': 4.61,
#   'Country': 'CA',
#   'Date': '2021-06-06 06:22:00',
#   'Current Description': 'few clouds'},
#  {'City': 'Bardiyah',
#   'Lat': 31.7561,
#   'Lng': 25.0865,
#   'Max Temp': 72.14,
#   'Humidity': 61,
#   'Cloudiness': 0,
#   'Wind Speed': 8.79,
#   'Country': 'LY',
#   'Date': '2021-06-06 06:26:57',
#   'Current Description': 'clear sky'},
#  {'City': 'Pereira Barreto',
#   'Lat': -20.6383,
#   'Lng': -51.1092,
#   'Max Temp': 67.87,
#   'Humidity': 44,
#   'Cloudiness': 74,
#   'Wind Speed': 6.42,
#   'Country': 'BR',
#   'Date': '2021-06-06 06:26:58',
#   'Current Description': 'broken clouds'},
#  {'City': 'Ponta Delgada',
#   'Lat': 37.7333,
#   'Lng': -25.6667,
#   'Max Temp': 59,
#   'Humidity': 94,
#   'Cloudiness': 20,
#   'Wind Speed': 2.3,
#   'Country': 'PT',
#   'Date': '2021-06-06 06:26:58',
#   'Current Description': 'few clouds'},
#  {'City': 'Berdsk',
#   'Lat': 54.7551,
#   'Lng': 83.0967,
#   'Max Temp': 72,
#   'Humidity': 49,
#   'Cloudiness': 0,
#   'Wind Speed': 17.9,
#   'Country': 'RU',
#   'Date': '2021-06-06 06:26:59',
#   'Current Description': 'clear sky'},
#  {'City': 'Ulladulla',
#   'Lat': -35.35,
#   'Lng': 150.4667,
#   'Max Temp': 64.09,
#   'Humidity': 52,
#   'Cloudiness': 12,
#   'Wind Speed': 6.8,
#   'Country': 'AU',
#   'Date': '2021-06-06 06:22:14',
#   'Current Description': 'few clouds'},
#  {'City': 'Praia Da Vitoria',
#   'Lat': 38.7333,
#   'Lng': -27.0667,
#   'Max Temp': 61.75,
#   'Humidity': 88,
#   'Cloudiness': 20,
#   'Wind Speed': 4,
#   'Country': 'PT',
#   'Date': '2021-06-06 06:26:59',
#   'Current Description': 'few clouds'},
#  {'City': 'Kaeo',
#   'Lat': -35.1,
#   'Lng': 173.7833,
#   'Max Temp': 61,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 11.99,
#   'Country': 'NZ',
#   'Date': '2021-06-06 06:27:00',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Bandarbeyla',
#   'Lat': 9.4942,
#   'Lng': 50.8122,
#   'Max Temp': 87.87,
#   'Humidity': 54,
#   'Cloudiness': 41,
#   'Wind Speed': 23.06,
#   'Country': 'SO',
#   'Date': '2021-06-06 06:27:01',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Budogoshch',
#   'Lat': 59.2816,
#   'Lng': 32.4707,
#   'Max Temp': 70.2,
#   'Humidity': 49,
#   'Cloudiness': 0,
#   'Wind Speed': 1.48,
#   'Country': 'RU',
#   'Date': '2021-06-06 06:27:01',
#   'Current Description': 'clear sky'},
#  {'City': 'Skibbereen',
#   'Lat': 51.55,
#   'Lng': -9.2667,
#   'Max Temp': 51.6,
#   'Humidity': 88,
#   'Cloudiness': 4,
#   'Wind Speed': 3.15,
#   'Country': 'IE',
#   'Date': '2021-06-06 06:27:02',
#   'Current Description': 'clear sky'},
#  {'City': 'Piacabucu',
#   'Lat': -10.4056,
#   'Lng': -36.4344,
#   'Max Temp': 74.57,
#   'Humidity': 84,
#   'Cloudiness': 14,
#   'Wind Speed': 6.26,
#   'Country': 'BR',
#   'Date': '2021-06-06 06:27:02',
#   'Current Description': 'few clouds'},
#  {'City': 'Bone',
#   'Lat': 51.9669,
#   'Lng': 12.1396,
#   'Max Temp': 66,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 1.39,
#   'Country': 'DE',
#   'Date': '2021-06-06 06:27:03',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Koboko',
#   'Lat': 3.4136,
#   'Lng': 30.9599,
#   'Max Temp': 68.04,
#   'Humidity': 87,
#   'Cloudiness': 99,
#   'Wind Speed': 8.66,
#   'Country': 'UG',
#   'Date': '2021-06-06 06:27:03',
#   'Current Description': 'light rain'},
#  {'City': 'Liku',
#   'Lat': -0.7275,
#   'Lng': 119.8922,
#   'Max Temp': 82.85,
#   'Humidity': 86,
#   'Cloudiness': 62,
#   'Wind Speed': 3.8,
#   'Country': 'ID',
#   'Date': '2021-06-06 06:27:04',
#   'Current Description': 'light rain'},
#  {'City': 'Bogorodskoye',
#   'Lat': 56.55,
#   'Lng': 37.8833,
#   'Max Temp': 65.57,
#   'Humidity': 65,
#   'Cloudiness': 1,
#   'Wind Speed': 7.87,
#   'Country': 'RU',
#   'Date': '2021-06-06 06:22:22',
#   'Current Description': 'clear sky'},
#  {'City': 'Kahului',
#   'Lat': 20.8947,
#   'Lng': -156.47,
#   'Max Temp': 76.84,
#   'Humidity': 75,
#   'Cloudiness': 1,
#   'Wind Speed': 19.57,
#   'Country': 'US',
#   'Date': '2021-06-06 06:22:51',
#   'Current Description': 'clear sky'},
#  {'City': 'Suslovo',
#   'Lat': 56.2167,
#   'Lng': 88.1167,
#   'Max Temp': 55.09,
#   'Humidity': 87,
#   'Cloudiness': 92,
#   'Wind Speed': 14.85,
#   'Country': 'RU',
#   'Date': '2021-06-06 06:27:05',
#   'Current Description': 'light rain'},
#  {'City': 'Lagoa',
#   'Lat': 39.05,
#   'Lng': -27.9833,
#   'Max Temp': 62.91,
#   'Humidity': 89,
#   'Cloudiness': 99,
#   'Wind Speed': 11.1,
#   'Country': 'PT',
#   'Date': '2021-06-06 06:27:05',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Saint Simons',
#   'Lat': 31.1352,
#   'Lng': -81.3901,
#   'Max Temp': 78.84,
#   'Humidity': 91,
#   'Cloudiness': 20,
#   'Wind Speed': 9.22,
#   'Country': 'US',
#   'Date': '2021-06-06 06:27:06',
#   'Current Description': 'few clouds'},
#  {'City': 'Kibala',
#   'Lat': 9.1104,
#   'Lng': 18.3463,
#   'Max Temp': 76.95,
#   'Humidity': 83,
#   'Cloudiness': 20,
#   'Wind Speed': 9.22,
#   'Country': 'TD',
#   'Date': '2021-06-06 06:27:06',
#   'Current Description': 'few clouds'},
#  {'City': 'Verkhnyaya Toyma',
#   'Lat': 62.2349,
#   'Lng': 44.9985,
#   'Max Temp': 76.37,
#   'Humidity': 34,
#   'Cloudiness': 56,
#   'Wind Speed': 3.13,
#   'Country': 'RU',
#   'Date': '2021-06-06 06:27:07',
#   'Current Description': 'broken clouds'},
#  {'City': 'Aguas De Lindoia',
#   'Lat': -22.4764,
#   'Lng': -46.6328,
#   'Max Temp': 49.62,
#   'Humidity': 63,
#   'Cloudiness': 52,
#   'Wind Speed': 4.59,
#   'Country': 'BR',
#   'Date': '2021-06-06 06:27:07',
#   'Current Description': 'broken clouds'},
#  {'City': 'Iaciara',
#   'Lat': -14.0958,
#   'Lng': -46.6317,
#   'Max Temp': 72.03,
#   'Humidity': 60,
#   'Cloudiness': 97,
#   'Wind Speed': 2.66,
#   'Country': 'BR',
#   'Date': '2021-06-06 06:27:08',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Ciudad Bolivar',
#   'Lat': 8.1222,
#   'Lng': -63.5497,
#   'Max Temp': 74.75,
#   'Humidity': 89,
#   'Cloudiness': 98,
#   'Wind Speed': 14.09,
#   'Country': 'VE',
#   'Date': '2021-06-06 06:27:08',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Yatou',
#   'Lat': 37.15,
#   'Lng': 122.3833,
#   'Max Temp': 82.33,
#   'Humidity': 35,
#   'Cloudiness': 9,
#   'Wind Speed': 15.26,
#   'Country': 'CN',
#   'Date': '2021-06-06 06:27:09',
#   'Current Description': 'clear sky'},
#  {'City': 'Marzuq',
#   'Lat': 14.4,
#   'Lng': 46.4667,
#   'Max Temp': 87.3,
#   'Humidity': 15,
#   'Cloudiness': 6,
#   'Wind Speed': 1.88,
#   'Country': 'YE',
#   'Date': '2021-06-06 06:27:10',
#   'Current Description': 'clear sky'},
#  {'City': 'Edd',
#   'Lat': 13.9297,
#   'Lng': 41.6925,
#   'Max Temp': 89.4,
#   'Humidity': 62,
#   'Cloudiness': 1,
#   'Wind Speed': 2.37,
#   'Country': 'ER',
#   'Date': '2021-06-06 06:27:11',
#   'Current Description': 'clear sky'},
#  {'City': 'Ulsteinvik',
#   'Lat': 62.3432,
#   'Lng': 5.8487,
#   'Max Temp': 63.16,
#   'Humidity': 94,
#   'Cloudiness': 94,
#   'Wind Speed': 4.38,
#   'Country': 'NO',
#   'Date': '2021-06-06 06:27:11',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Chandpur',
#   'Lat': 29.15,
#   'Lng': 78.2667,
#   'Max Temp': 103.1,
#   'Humidity': 21,
#   'Cloudiness': 14,
#   'Wind Speed': 4.03,
#   'Country': 'IN',
#   'Date': '2021-06-06 06:27:12',
#   'Current Description': 'few clouds'},
#  {'City': 'Mocuba',
#   'Lat': -16.8392,
#   'Lng': 36.9856,
#   'Max Temp': 64.15,
#   'Humidity': 88,
#   'Cloudiness': 48,
#   'Wind Speed': 7.09,
#   'Country': 'MZ',
#   'Date': '2021-06-06 06:27:12',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Werda',
#   'Lat': -25.2667,
#   'Lng': 23.2833,
#   'Max Temp': 45.23,
#   'Humidity': 58,
#   'Cloudiness': 0,
#   'Wind Speed': 10.27,
#   'Country': 'BW',
#   'Date': '2021-06-06 06:27:13',
#   'Current Description': 'clear sky'},
#  {'City': 'Venado Tuerto',
#   'Lat': -33.7456,
#   'Lng': -61.9688,
#   'Max Temp': 48.88,
#   'Humidity': 52,
#   'Cloudiness': 81,
#   'Wind Speed': 6.04,
#   'Country': 'AR',
#   'Date': '2021-06-06 06:27:13',
#   'Current Description': 'broken clouds'},
#  {'City': 'Tongchuan',
#   'Lat': 35.0806,
#   'Lng': 109.0897,
#   'Max Temp': 95.41,
#   'Humidity': 14,
#   'Cloudiness': 73,
#   'Wind Speed': 8.86,
#   'Country': 'CN',
#   'Date': '2021-06-06 06:27:14',
#   'Current Description': 'light rain'},
#  {'City': 'Marystown',
#   'Lat': 47.1666,
#   'Lng': -55.1483,
#   'Max Temp': 51.85,
#   'Humidity': 100,
#   'Cloudiness': 100,
#   'Wind Speed': 10.63,
#   'Country': 'CA',
#   'Date': '2021-06-06 06:27:15',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Barranco',
#   'Lat': 9.5167,
#   'Lng': -82.7,
#   'Max Temp': 75.02,
#   'Humidity': 89,
#   'Cloudiness': 52,
#   'Wind Speed': 3.47,
#   'Country': 'PA',
#   'Date': '2021-06-06 06:27:15',
#   'Current Description': 'broken clouds'},
#  {'City': 'Elizabeth City',
#   'Lat': 36.2946,
#   'Lng': -76.2511,
#   'Max Temp': 71.01,
#   'Humidity': 97,
#   'Cloudiness': 0,
#   'Wind Speed': 6.51,
#   'Country': 'US',
#   'Date': '2021-06-06 06:23:37',
#   'Current Description': 'clear sky'},
#  {'City': 'Vuktyl',
#   'Lat': 63.8567,
#   'Lng': 57.3094,
#   'Max Temp': 59.67,
#   'Humidity': 47,
#   'Cloudiness': 73,
#   'Wind Speed': 12.28,
#   'Country': 'RU',
#   'Date': '2021-06-06 06:27:16',
#   'Current Description': 'broken clouds'},
#  {'City': 'San Nicolas',
#   'Lat': 18.1725,
#   'Lng': 120.5953,
#   'Max Temp': 86,
#   'Humidity': 79,
#   'Cloudiness': 75,
#   'Wind Speed': 9.22,
#   'Country': 'PH',
#   'Date': '2021-06-06 06:27:17',
#   'Current Description': 'broken clouds'},
#  {'City': 'Laguna',
#   'Lat': 38.421,
#   'Lng': -121.4238,
#   'Max Temp': 78.64,
#   'Humidity': 47,
#   'Cloudiness': 1,
#   'Wind Speed': 1.99,
#   'Country': 'US',
#   'Date': '2021-06-06 06:27:17',
#   'Current Description': 'clear sky'},
#  {'City': 'Neuquen',
#   'Lat': -38.9516,
#   'Lng': -68.0591,
#   'Max Temp': 46.96,
#   'Humidity': 46,
#   'Cloudiness': 92,
#   'Wind Speed': 9.04,
#   'Country': 'AR',
#   'Date': '2021-06-06 06:22:25',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Kungurtug',
#   'Lat': 50.5994,
#   'Lng': 97.5228,
#   'Max Temp': 49.14,
#   'Humidity': 52,
#   'Cloudiness': 95,
#   'Wind Speed': 8.81,
#   'Country': 'RU',
#   'Date': '2021-06-06 06:27:17',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Naze',
#   'Lat': 28.3667,
#   'Lng': 129.4833,
#   'Max Temp': 75.2,
#   'Humidity': 94,
#   'Cloudiness': 75,
#   'Wind Speed': 14.97,
#   'Country': 'JP',
#   'Date': '2021-06-06 06:27:18',
#   'Current Description': 'moderate rain'},
#  {'City': 'Buraydah',
#   'Lat': 26.326,
#   'Lng': 43.975,
#   'Max Temp': 99.05,
#   'Humidity': 9,
#   'Cloudiness': 1,
#   'Wind Speed': 15.59,
#   'Country': 'SA',
#   'Date': '2021-06-06 06:27:19',
#   'Current Description': 'clear sky'},
#  {'City': 'Mahajanga',
#   'Lat': -15.7167,
#   'Lng': 46.3167,
#   'Max Temp': 78.8,
#   'Humidity': 61,
#   'Cloudiness': 0,
#   'Wind Speed': 5.75,
#   'Country': 'MG',
#   'Date': '2021-06-06 06:27:20',
#   'Current Description': 'clear sky'},
#  {'City': 'Mayumba',
#   'Lat': -3.432,
#   'Lng': 10.6554,
#   'Max Temp': 75.85,
#   'Humidity': 92,
#   'Cloudiness': 87,
#   'Wind Speed': 5.73,
#   'Country': 'GA',
#   'Date': '2021-06-06 06:27:20',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Khonsa',
#   'Lat': 27.0167,
#   'Lng': 95.5667,
#   'Max Temp': 69.62,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 1.54,
#   'Country': 'IN',
#   'Date': '2021-06-06 06:27:20',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Ayia Galini',
#   'Lat': 35.1,
#   'Lng': 24.6833,
#   'Max Temp': 75.99,
#   'Humidity': 39,
#   'Cloudiness': 0,
#   'Wind Speed': 2.68,
#   'Country': 'GR',
#   'Date': '2021-06-06 06:27:21',
#   'Current Description': 'clear sky'},
#  {'City': 'Lola',
#   'Lat': 7.8,
#   'Lng': -8.5333,
#   'Max Temp': 69.96,
#   'Humidity': 99,
#   'Cloudiness': 97,
#   'Wind Speed': 2.55,
#   'Country': 'GN',
#   'Date': '2021-06-06 06:27:21',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Straumen',
#   'Lat': 63.8709,
#   'Lng': 11.2999,
#   'Max Temp': 61.63,
#   'Humidity': 68,
#   'Cloudiness': 80,
#   'Wind Speed': 0.67,
#   'Country': 'NO',
#   'Date': '2021-06-06 06:27:22',
#   'Current Description': 'broken clouds'},
#  {'City': 'Antalaha',
#   'Lat': -14.9003,
#   'Lng': 50.2788,
#   'Max Temp': 77.74,
#   'Humidity': 73,
#   'Cloudiness': 99,
#   'Wind Speed': 6.26,
#   'Country': 'MG',
#   'Date': '2021-06-06 06:27:22',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Ramgarh',
#   'Lat': 23.6333,
#   'Lng': 85.5167,
#   'Max Temp': 95.05,
#   'Humidity': 31,
#   'Cloudiness': 63,
#   'Wind Speed': 12.73,
#   'Country': 'IN',
#   'Date': '2021-06-06 06:27:23',
#   'Current Description': 'broken clouds'},
#  {'City': 'Baykit',
#   'Lat': 61.67,
#   'Lng': 96.37,
#   'Max Temp': 45.93,
#   'Humidity': 48,
#   'Cloudiness': 94,
#   'Wind Speed': 14.18,
#   'Country': 'RU',
#   'Date': '2021-06-06 06:24:43',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Rio Negrinho',
#   'Lat': -26.2544,
#   'Lng': -49.5183,
#   'Max Temp': 60.71,
#   'Humidity': 92,
#   'Cloudiness': 92,
#   'Wind Speed': 3.36,
#   'Country': 'BR',
#   'Date': '2021-06-06 06:27:23',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Kuminskiy',
#   'Lat': 58.6667,
#   'Lng': 66.5667,
#   'Max Temp': 77.36,
#   'Humidity': 33,
#   'Cloudiness': 7,
#   'Wind Speed': 11.79,
#   'Country': 'RU',
#   'Date': '2021-06-06 06:27:24',
#   'Current Description': 'clear sky'},
#  {'City': 'Hvolsvollur',
#   'Lat': 63.7533,
#   'Lng': -20.2243,
#   'Max Temp': 45.81,
#   'Humidity': 81,
#   'Cloudiness': 99,
#   'Wind Speed': 3.89,
#   'Country': 'IS',
#   'Date': '2021-06-06 06:27:24',
#   'Current Description': 'light rain'},
#  {'City': 'Khorramshahr',
#   'Lat': 30.4397,
#   'Lng': 48.1664,
#   'Max Temp': 107.56,
#   'Humidity': 15,
#   'Cloudiness': 0,
#   'Wind Speed': 11.5,
#   'Country': 'IR',
#   'Date': '2021-06-06 06:27:24',
#   'Current Description': 'clear sky'},
#  {'City': 'Lamu',
#   'Lat': -2.2717,
#   'Lng': 40.902,
#   'Max Temp': 78.44,
#   'Humidity': 82,
#   'Cloudiness': 51,
#   'Wind Speed': 16.87,
#   'Country': 'KE',
#   'Date': '2021-06-06 06:27:25',
#   'Current Description': 'light rain'}]

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Rio Gallegos -51.6226  -69.2181     35.65        69           0
# 1       Rikitea -23.1203 -134.9692     76.05        83          72
# 2        Suntar  62.1444  117.6319     52.77        73         100
# 3        Bethel  41.3712  -73.4140     76.19        73           1
# 4         Ancud -41.8697  -73.8203     46.22        83          96
# 5       Samarai -10.6167  150.6667     78.33        87          94
# 6       Darlowo  54.4210   16.4107     60.94        65          13
# 7     Upernavik  72.7868  -56.1549     33.51        83           2
# 8        Soubre   5.7856   -6.6083     71.96        99          74
# 9     Nishihara  26.1842  127.7558     85.66        76          75
#
#    Wind Speed Country                 Date Current Description
# 0       11.50      AR  2021-06-06 06:21:27           clear sky
# 1       15.90      PF  2021-06-06 06:21:49          light rain
# 2        2.91      RU  2021-06-06 06:21:49     overcast clouds
# 3        0.00      US  2021-06-06 06:21:49           clear sky
# 4        4.76      CL  2021-06-06 06:21:50     overcast clouds
# 5       16.28      PG  2021-06-06 06:21:50          light rain
# 6        4.05      PL  2021-06-06 06:21:50          few clouds
# 7        3.13      GL  2021-06-06 06:21:51           clear sky
# 8        2.08      CI  2021-06-06 06:21:52       broken clouds
# 9       17.76      JP  2021-06-06 06:21:53       broken clouds

# %%
# Reorder columns of city_data_df
new_column_order = ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

city_data_df = city_data_df[new_column_order]

city_data_df.head(10)
# Out:
#            City Country                 Date      Lat       Lng  Max Temp  \
# 0  Rio Gallegos      AR  2021-06-06 06:21:27 -51.6226  -69.2181     35.65
# 1       Rikitea      PF  2021-06-06 06:21:49 -23.1203 -134.9692     76.05
# 2        Suntar      RU  2021-06-06 06:21:49  62.1444  117.6319     52.77
# 3        Bethel      US  2021-06-06 06:21:49  41.3712  -73.4140     76.19
# 4         Ancud      CL  2021-06-06 06:21:50 -41.8697  -73.8203     46.22
# 5       Samarai      PG  2021-06-06 06:21:50 -10.6167  150.6667     78.33
# 6       Darlowo      PL  2021-06-06 06:21:50  54.4210   16.4107     60.94
# 7     Upernavik      GL  2021-06-06 06:21:51  72.7868  -56.1549     33.51
# 8        Soubre      CI  2021-06-06 06:21:52   5.7856   -6.6083     71.96
# 9     Nishihara      JP  2021-06-06 06:21:53  26.1842  127.7558     85.66
#
#    Humidity  Cloudiness  Wind Speed Current Description
# 0        69           0       11.50           clear sky
# 1        83          72       15.90          light rain
# 2        73         100        2.91     overcast clouds
# 3        73           1        0.00           clear sky
# 4        83          96        4.76     overcast clouds
# 5        87          94       16.28          light rain
# 6        65          13        4.05          few clouds
# 7        83           2        3.13           clear sky
# 8        99          74        2.08       broken clouds
# 9        76          75       17.76       broken clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
